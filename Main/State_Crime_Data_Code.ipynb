# %%
import requests
import pandas as pd
import time
from config import api_key

# Define the date range for the data query
begin_date = "01-2000"
end_date = "12-2023"
time_frame = f'?from={begin_date}&to={end_date}'

# List of crime types for which data will be fetched
crime = ["homicide", "rape", "robbery", "aggravated-assault", "arson", "burglary", "larceny", "motor-vehicle-theft"]

# Dictionary of states with their abbreviations and full names
states = {
    "AK": "Alaska", "AL": "Alabama", "AR": "Arkansas", "AZ": "Arizona",
    "CA": "California", "CO": "Colorado", "CT": "Connecticut", "DC": "District of Columbia",
    "DE": "Delaware", "FL": "Florida", "GA": "Georgia", "HI": "Hawaii",
    "IA": "Iowa", "ID": "Idaho", "IL": "Illinois", "IN": "Indiana",
    "KS": "Kansas", "KY": "Kentucky", "LA": "Louisiana", "MA": "Massachusetts",
    "MD": "Maryland", "ME": "Maine", "MI": "Michigan", "MN": "Minnesota",
    "MO": "Missouri", "MS": "Mississippi", "MT": "Montana", "NC": "North Carolina",
    "ND": "North Dakota", "NE": "Nebraska", "NH": "New Hampshire", "NJ": "New Jersey",
    "NM": "New Mexico", "NV": "Nevada", "NY": "New York", "OH": "Ohio",
    "OK": "Oklahoma", "OR": "Oregon", "PA": "Pennsylvania", "RI": "Rhode Island",
    "SC": "South Carolina", "SD": "South Dakota", "TN": "Tennessee", "TX": "Texas",
    "UT": "Utah", "VA": "Virginia", "VT": "Vermont", "WA": "Washington",
    "WI": "Wisconsin", "WV": "West Virginia", "WY": "Wyoming"
}

# Function to fetch crime data from the API
def fetch_crime_data(crime, state_code, time_frame, api_key):
    base_url = f'https://api.usa.gov/crime/fbi/cde/summarized/state/{state_code}/{crime}{time_frame}{api_key}'
    response = requests.get(base_url)
    if response.status_code != 200:
        raise ValueError(f"API call failed with status {response.status_code}")
    return response.json()

# Function to process the fetched crime data into a DataFrame
def process_crime_data(crime_data, state_name):
    # Define the columns to extract from the crime data
    data_columns = {
        "Total Crimes": f"offenses.actuals.{state_name}",
        "Clearances": f"offenses.actuals.{state_name} Clearances",
        "Crime(Per 100k)": f"offenses.rates.{state_name}",
        "Prosecutions(Per 100k)": f"offenses.rates.{state_name} Clearances",
        "Total Pop": f"populations.population.{state_name}",
        "Partic Pop": f"populations.participated_population.{state_name}",
        "Pop Coverage": f"tooltips.Percent of Population Coverage.{state_name}"
    }
    
    result = {}
    for col_name, key_path in data_columns.items():
        # Navigate through the nested JSON data structure to extract values
        keys = key_path.split(".")
        data = crime_data
        for key in keys:
            data = data.get(key, {})
        result[col_name] = list(data.values())
    
    return pd.DataFrame(result, index=list(data.keys()))

# Create a dictionary to hold data for each crime type
crime_data_dict = {c: [] for c in crime}

# Loop over each state and each crime type to fetch and process the data
for state_code, state_name in states.items():
    for c in crime:
        try:
            # Fetch crime data for the state and crime
            crime_data = fetch_crime_data(c, state_code, time_frame, api_key)
            
            # Process the crime data into a DataFrame
            df_crime_data = process_crime_data(crime_data, state_name)
            
            # Add state abbreviation and crime type as columns
            df_crime_data["State"] = state_code
            df_crime_data["Crime"] = c
            
            # Convert the index (months) to DateTime format and reset the index
            df_crime_data.index = pd.to_datetime(df_crime_data.index, format='%m-%Y', errors='coerce')
            df_crime_data = df_crime_data.reset_index().rename(columns={"index": "Month"})
            
            # Append the data to the crime_data_dict under the corresponding crime type
            crime_data_dict[c].append(df_crime_data)
            
            print(f"Processed data for {state_name} ({state_code}) - {c}")
        except Exception as e:
            print(f"Error processing {state_name} ({state_code}) - {c}: {e}")
    
    # Pause to avoid overloading the API
    time.sleep(2)

# Save each crime type to a separate CSV file
for c, data in crime_data_dict.items():
    # Combine data for the crime type into a single DataFrame and calculate Prosecuted %
    all_data_df = pd.concat(data, ignore_index=True)
    all_data_df["Prosecuted %"] = (all_data_df["Clearances"] / all_data_df["Total Crimes"]).round(2)
    
    # Sort by State and Month
    all_data_df = all_data_df.sort_values(by=["State", "Month"])
    
    # Reorder columns as needed
    reorder = ["Month", "State", "Total Crimes", "Clearances", "Prosecuted %", "Crime(Per 100k)", "Prosecutions(Per 100k)", "Total Pop", "Partic Pop", "Pop Coverage", "Crime"]
    all_data_df = all_data_df[reorder]
    
    # Save the combined DataFrame to a CSV file
    all_data_df.to_csv(f"../Resources/State/{c}_state_crime_data.csv", index=False)

    # Log the successful saving of the file
    print(f"All data for {c} saved to '../Resources/State/{c}_state_crime_data.csv'")
# Out:
# Processed data for Alaska (AK) - homicide
# Processed data for Alaska (AK) - rape
# Processed data for Alaska (AK) - robbery
# Processed data for Alaska (AK) - aggravated-assault
# Processed data for Alaska (AK) - arson
# Processed data for Alaska (AK) - burglary
# Processed data for Alaska (AK) - larceny
# Processed data for Alaska (AK) - motor-vehicle-theft
# Processed data for Alabama (AL) - homicide
# Processed data for Alabama (AL) - rape
# Processed data for Alabama (AL) - robbery
# Processed data for Alabama (AL) - aggravated-assault
# Processed data for Alabama (AL) - arson
# Processed data for Alabama (AL) - burglary
# Processed data for Alabama (AL) - larceny
# Processed data for Alabama (AL) - motor-vehicle-theft
# Processed data for Arkansas (AR) - homicide
# Processed data for Arkansas (AR) - rape
# Processed data for Arkansas (AR) - robbery
# Processed data for Arkansas (AR) - aggravated-assault
# Processed data for Arkansas (AR) - arson
# Processed data for Arkansas (AR) - burglary
# Processed data for Arkansas (AR) - larceny
# Processed data for Arkansas (AR) - motor-vehicle-theft
# Processed data for Arizona (AZ) - homicide
# Processed data for Arizona (AZ) - rape
# Processed data for Arizona (AZ) - robbery
# Processed data for Arizona (AZ) - aggravated-assault
# Processed data for Arizona (AZ) - arson
# Processed data for Arizona (AZ) - burglary
# Processed data for Arizona (AZ) - larceny
# Processed data for Arizona (AZ) - motor-vehicle-theft
# Processed data for California (CA) - homicide
# Processed data for California (CA) - rape
# Processed data for California (CA) - robbery
# Processed data for California (CA) - aggravated-assault
# Processed data for California (CA) - arson
# Processed data for California (CA) - burglary
# Processed data for California (CA) - larceny
# Processed data for California (CA) - motor-vehicle-theft
# Processed data for Colorado (CO) - homicide
# Processed data for Colorado (CO) - rape
# Processed data for Colorado (CO) - robbery
# Processed data for Colorado (CO) - aggravated-assault
# Processed data for Colorado (CO) - arson
# Processed data for Colorado (CO) - burglary
# Processed data for Colorado (CO) - larceny
# Processed data for Colorado (CO) - motor-vehicle-theft
# Processed data for Connecticut (CT) - homicide
# Processed data for Connecticut (CT) - rape
# Processed data for Connecticut (CT) - robbery
# Processed data for Connecticut (CT) - aggravated-assault
# Processed data for Connecticut (CT) - arson
# Processed data for Connecticut (CT) - burglary
# Processed data for Connecticut (CT) - larceny
# Processed data for Connecticut (CT) - motor-vehicle-theft
# Processed data for District of Columbia (DC) - homicide
# Processed data for District of Columbia (DC) - rape
# Processed data for District of Columbia (DC) - robbery
# Processed data for District of Columbia (DC) - aggravated-assault
# Processed data for District of Columbia (DC) - arson
# Processed data for District of Columbia (DC) - burglary
# Processed data for District of Columbia (DC) - larceny
# Processed data for District of Columbia (DC) - motor-vehicle-theft
# Processed data for Delaware (DE) - homicide
# Processed data for Delaware (DE) - rape
# Processed data for Delaware (DE) - robbery
# Processed data for Delaware (DE) - aggravated-assault
# Processed data for Delaware (DE) - arson
# Processed data for Delaware (DE) - burglary
# Processed data for Delaware (DE) - larceny
# Processed data for Delaware (DE) - motor-vehicle-theft
# Processed data for Florida (FL) - homicide
# Processed data for Florida (FL) - rape
# Processed data for Florida (FL) - robbery
# Processed data for Florida (FL) - aggravated-assault
# Processed data for Florida (FL) - arson
# Processed data for Florida (FL) - burglary
# Processed data for Florida (FL) - larceny
# Processed data for Florida (FL) - motor-vehicle-theft
# Processed data for Georgia (GA) - homicide
# Processed data for Georgia (GA) - rape
# Processed data for Georgia (GA) - robbery
# Processed data for Georgia (GA) - aggravated-assault
# Processed data for Georgia (GA) - arson
# Processed data for Georgia (GA) - burglary
# Processed data for Georgia (GA) - larceny
# Processed data for Georgia (GA) - motor-vehicle-theft
# Processed data for Hawaii (HI) - homicide
# Processed data for Hawaii (HI) - rape
# Processed data for Hawaii (HI) - robbery
# Processed data for Hawaii (HI) - aggravated-assault
# Processed data for Hawaii (HI) - arson
# Processed data for Hawaii (HI) - burglary
# Processed data for Hawaii (HI) - larceny
# Processed data for Hawaii (HI) - motor-vehicle-theft
# Processed data for Iowa (IA) - homicide
# Processed data for Iowa (IA) - rape
# Processed data for Iowa (IA) - robbery
# Processed data for Iowa (IA) - aggravated-assault
# Processed data for Iowa (IA) - arson
# Processed data for Iowa (IA) - burglary
# Processed data for Iowa (IA) - larceny
# Processed data for Iowa (IA) - motor-vehicle-theft
# Processed data for Idaho (ID) - homicide
# Processed data for Idaho (ID) - rape
# Processed data for Idaho (ID) - robbery
# Processed data for Idaho (ID) - aggravated-assault
# Processed data for Idaho (ID) - arson
# Processed data for Idaho (ID) - burglary
# Processed data for Idaho (ID) - larceny
# Processed data for Idaho (ID) - motor-vehicle-theft
# Processed data for Illinois (IL) - homicide
# Processed data for Illinois (IL) - rape
# Processed data for Illinois (IL) - robbery
# Processed data for Illinois (IL) - aggravated-assault
# Processed data for Illinois (IL) - arson
# Processed data for Illinois (IL) - burglary
# Processed data for Illinois (IL) - larceny
# Processed data for Illinois (IL) - motor-vehicle-theft
# Processed data for Indiana (IN) - homicide
# Processed data for Indiana (IN) - rape
# Processed data for Indiana (IN) - robbery
# Processed data for Indiana (IN) - aggravated-assault
# Processed data for Indiana (IN) - arson
# Processed data for Indiana (IN) - burglary
# Processed data for Indiana (IN) - larceny
# Processed data for Indiana (IN) - motor-vehicle-theft
# Processed data for Kansas (KS) - homicide
# Processed data for Kansas (KS) - rape
# Processed data for Kansas (KS) - robbery
# Processed data for Kansas (KS) - aggravated-assault
# Processed data for Kansas (KS) - arson
# Processed data for Kansas (KS) - burglary
# Processed data for Kansas (KS) - larceny
# Processed data for Kansas (KS) - motor-vehicle-theft
# Processed data for Kentucky (KY) - homicide
# Processed data for Kentucky (KY) - rape
# Processed data for Kentucky (KY) - robbery
# Processed data for Kentucky (KY) - aggravated-assault
# Processed data for Kentucky (KY) - arson
# Processed data for Kentucky (KY) - burglary
# Processed data for Kentucky (KY) - larceny
# Processed data for Kentucky (KY) - motor-vehicle-theft
# Processed data for Louisiana (LA) - homicide
# Processed data for Louisiana (LA) - rape
# Processed data for Louisiana (LA) - robbery
# Processed data for Louisiana (LA) - aggravated-assault
# Processed data for Louisiana (LA) - arson
# Processed data for Louisiana (LA) - burglary
# Processed data for Louisiana (LA) - larceny
# Processed data for Louisiana (LA) - motor-vehicle-theft
# Processed data for Massachusetts (MA) - homicide
# Processed data for Massachusetts (MA) - rape
# Processed data for Massachusetts (MA) - robbery
# Processed data for Massachusetts (MA) - aggravated-assault
# Processed data for Massachusetts (MA) - arson
# Processed data for Massachusetts (MA) - burglary
# Processed data for Massachusetts (MA) - larceny
# Processed data for Massachusetts (MA) - motor-vehicle-theft
# Processed data for Maryland (MD) - homicide
# Processed data for Maryland (MD) - rape
# Processed data for Maryland (MD) - robbery
# Processed data for Maryland (MD) - aggravated-assault
# Processed data for Maryland (MD) - arson
# Processed data for Maryland (MD) - burglary
# Processed data for Maryland (MD) - larceny
# Processed data for Maryland (MD) - motor-vehicle-theft
# Processed data for Maine (ME) - homicide
# Processed data for Maine (ME) - rape
# Processed data for Maine (ME) - robbery
# Processed data for Maine (ME) - aggravated-assault
# Processed data for Maine (ME) - arson
# Processed data for Maine (ME) - burglary
# Processed data for Maine (ME) - larceny
# Processed data for Maine (ME) - motor-vehicle-theft
# Processed data for Michigan (MI) - homicide
# Processed data for Michigan (MI) - rape
# Processed data for Michigan (MI) - robbery
# Processed data for Michigan (MI) - aggravated-assault
# Processed data for Michigan (MI) - arson
# Processed data for Michigan (MI) - burglary
# Processed data for Michigan (MI) - larceny
# Processed data for Michigan (MI) - motor-vehicle-theft
# Processed data for Minnesota (MN) - homicide
# Processed data for Minnesota (MN) - rape
# Processed data for Minnesota (MN) - robbery
# Processed data for Minnesota (MN) - aggravated-assault
# Processed data for Minnesota (MN) - arson
# Processed data for Minnesota (MN) - burglary
# Processed data for Minnesota (MN) - larceny
# Processed data for Minnesota (MN) - motor-vehicle-theft
# Processed data for Missouri (MO) - homicide
# Processed data for Missouri (MO) - rape
# Processed data for Missouri (MO) - robbery
# Processed data for Missouri (MO) - aggravated-assault
# Processed data for Missouri (MO) - arson
# Processed data for Missouri (MO) - burglary
# Processed data for Missouri (MO) - larceny
# Processed data for Missouri (MO) - motor-vehicle-theft
# Processed data for Mississippi (MS) - homicide
# Processed data for Mississippi (MS) - rape
# Processed data for Mississippi (MS) - robbery
# Processed data for Mississippi (MS) - aggravated-assault
# Processed data for Mississippi (MS) - arson
# Processed data for Mississippi (MS) - burglary
# Processed data for Mississippi (MS) - larceny
# Processed data for Mississippi (MS) - motor-vehicle-theft
# Processed data for Montana (MT) - homicide
# Processed data for Montana (MT) - rape
# Processed data for Montana (MT) - robbery
# Processed data for Montana (MT) - aggravated-assault
# Processed data for Montana (MT) - arson
# Processed data for Montana (MT) - burglary
# Processed data for Montana (MT) - larceny
# Processed data for Montana (MT) - motor-vehicle-theft
# Processed data for North Carolina (NC) - homicide
# Processed data for North Carolina (NC) - rape
# Processed data for North Carolina (NC) - robbery
# Processed data for North Carolina (NC) - aggravated-assault
# Processed data for North Carolina (NC) - arson
# Processed data for North Carolina (NC) - burglary
# Processed data for North Carolina (NC) - larceny
# Processed data for North Carolina (NC) - motor-vehicle-theft
# Processed data for North Dakota (ND) - homicide
# Processed data for North Dakota (ND) - rape
# Processed data for North Dakota (ND) - robbery
# Processed data for North Dakota (ND) - aggravated-assault
# Processed data for North Dakota (ND) - arson
# Processed data for North Dakota (ND) - burglary
# Processed data for North Dakota (ND) - larceny
# Processed data for North Dakota (ND) - motor-vehicle-theft
# Processed data for Nebraska (NE) - homicide
# Processed data for Nebraska (NE) - rape
# Processed data for Nebraska (NE) - robbery
# Processed data for Nebraska (NE) - aggravated-assault
# Processed data for Nebraska (NE) - arson
# Processed data for Nebraska (NE) - burglary
# Processed data for Nebraska (NE) - larceny
# Processed data for Nebraska (NE) - motor-vehicle-theft
# Processed data for New Hampshire (NH) - homicide
# Processed data for New Hampshire (NH) - rape
# Processed data for New Hampshire (NH) - robbery
# Processed data for New Hampshire (NH) - aggravated-assault
# Processed data for New Hampshire (NH) - arson
# Processed data for New Hampshire (NH) - burglary
# Processed data for New Hampshire (NH) - larceny
# Processed data for New Hampshire (NH) - motor-vehicle-theft
# Processed data for New Jersey (NJ) - homicide
# Processed data for New Jersey (NJ) - rape
# Processed data for New Jersey (NJ) - robbery
# Processed data for New Jersey (NJ) - aggravated-assault
# Processed data for New Jersey (NJ) - arson
# Processed data for New Jersey (NJ) - burglary
# Processed data for New Jersey (NJ) - larceny
# Processed data for New Jersey (NJ) - motor-vehicle-theft
# Processed data for New Mexico (NM) - homicide
# Processed data for New Mexico (NM) - rape
# Processed data for New Mexico (NM) - robbery
# Processed data for New Mexico (NM) - aggravated-assault
# Processed data for New Mexico (NM) - arson
# Processed data for New Mexico (NM) - burglary
# Processed data for New Mexico (NM) - larceny
# Processed data for New Mexico (NM) - motor-vehicle-theft
# Processed data for Nevada (NV) - homicide
# Processed data for Nevada (NV) - rape
# Processed data for Nevada (NV) - robbery
# Processed data for Nevada (NV) - aggravated-assault
# Processed data for Nevada (NV) - arson
# Processed data for Nevada (NV) - burglary
# Processed data for Nevada (NV) - larceny
# Processed data for Nevada (NV) - motor-vehicle-theft
# Processed data for New York (NY) - homicide
# Processed data for New York (NY) - rape
# Processed data for New York (NY) - robbery
# Processed data for New York (NY) - aggravated-assault
# Processed data for New York (NY) - arson
# Processed data for New York (NY) - burglary
# Processed data for New York (NY) - larceny
# Processed data for New York (NY) - motor-vehicle-theft
# Processed data for Ohio (OH) - homicide
# Processed data for Ohio (OH) - rape
# Processed data for Ohio (OH) - robbery
# Processed data for Ohio (OH) - aggravated-assault
# Processed data for Ohio (OH) - arson
# Processed data for Ohio (OH) - burglary
# Processed data for Ohio (OH) - larceny
# Processed data for Ohio (OH) - motor-vehicle-theft
# Processed data for Oklahoma (OK) - homicide
# Processed data for Oklahoma (OK) - rape
# Processed data for Oklahoma (OK) - robbery
# Processed data for Oklahoma (OK) - aggravated-assault
# Processed data for Oklahoma (OK) - arson
# Processed data for Oklahoma (OK) - burglary
# Processed data for Oklahoma (OK) - larceny
# Processed data for Oklahoma (OK) - motor-vehicle-theft
# Processed data for Oregon (OR) - homicide
# Processed data for Oregon (OR) - rape
# Processed data for Oregon (OR) - robbery
# Processed data for Oregon (OR) - aggravated-assault
# Processed data for Oregon (OR) - arson
# Processed data for Oregon (OR) - burglary
# Processed data for Oregon (OR) - larceny
# Processed data for Oregon (OR) - motor-vehicle-theft
# Processed data for Pennsylvania (PA) - homicide
# Processed data for Pennsylvania (PA) - rape
# Processed data for Pennsylvania (PA) - robbery
# Processed data for Pennsylvania (PA) - aggravated-assault
# Processed data for Pennsylvania (PA) - arson
# Processed data for Pennsylvania (PA) - burglary
# Processed data for Pennsylvania (PA) - larceny
# Processed data for Pennsylvania (PA) - motor-vehicle-theft
# Processed data for Rhode Island (RI) - homicide
# Processed data for Rhode Island (RI) - rape
# Processed data for Rhode Island (RI) - robbery
# Processed data for Rhode Island (RI) - aggravated-assault
# Processed data for Rhode Island (RI) - arson
# Processed data for Rhode Island (RI) - burglary
# Processed data for Rhode Island (RI) - larceny
# Processed data for Rhode Island (RI) - motor-vehicle-theft
# Processed data for South Carolina (SC) - homicide
# Processed data for South Carolina (SC) - rape
# Processed data for South Carolina (SC) - robbery
# Processed data for South Carolina (SC) - aggravated-assault
# Processed data for South Carolina (SC) - arson
# Processed data for South Carolina (SC) - burglary
# Processed data for South Carolina (SC) - larceny
# Processed data for South Carolina (SC) - motor-vehicle-theft
# Processed data for South Dakota (SD) - homicide
# Processed data for South Dakota (SD) - rape
# Processed data for South Dakota (SD) - robbery
# Processed data for South Dakota (SD) - aggravated-assault
# Processed data for South Dakota (SD) - arson
# Processed data for South Dakota (SD) - burglary
# Processed data for South Dakota (SD) - larceny
# Processed data for South Dakota (SD) - motor-vehicle-theft
# Processed data for Tennessee (TN) - homicide
# Processed data for Tennessee (TN) - rape
# Processed data for Tennessee (TN) - robbery
# Processed data for Tennessee (TN) - aggravated-assault
# Processed data for Tennessee (TN) - arson
# Processed data for Tennessee (TN) - burglary
# Processed data for Tennessee (TN) - larceny
# Processed data for Tennessee (TN) - motor-vehicle-theft
# Processed data for Texas (TX) - homicide
# Processed data for Texas (TX) - rape
# Processed data for Texas (TX) - robbery
# Processed data for Texas (TX) - aggravated-assault
# Processed data for Texas (TX) - arson
# Processed data for Texas (TX) - burglary
# Processed data for Texas (TX) - larceny
# Processed data for Texas (TX) - motor-vehicle-theft
# Processed data for Utah (UT) - homicide
# Processed data for Utah (UT) - rape
# Processed data for Utah (UT) - robbery
# Processed data for Utah (UT) - aggravated-assault
# Processed data for Utah (UT) - arson
# Processed data for Utah (UT) - burglary
# Processed data for Utah (UT) - larceny
# Processed data for Utah (UT) - motor-vehicle-theft
# Processed data for Virginia (VA) - homicide
# Processed data for Virginia (VA) - rape
# Processed data for Virginia (VA) - robbery
# Processed data for Virginia (VA) - aggravated-assault
# Processed data for Virginia (VA) - arson
# Processed data for Virginia (VA) - burglary
# Processed data for Virginia (VA) - larceny
# Processed data for Virginia (VA) - motor-vehicle-theft
# Processed data for Vermont (VT) - homicide
# Processed data for Vermont (VT) - rape
# Processed data for Vermont (VT) - robbery
# Processed data for Vermont (VT) - aggravated-assault
# Processed data for Vermont (VT) - arson
# Processed data for Vermont (VT) - burglary
# Processed data for Vermont (VT) - larceny
# Processed data for Vermont (VT) - motor-vehicle-theft
# Processed data for Washington (WA) - homicide
# Processed data for Washington (WA) - rape
# Processed data for Washington (WA) - robbery
# Processed data for Washington (WA) - aggravated-assault
# Processed data for Washington (WA) - arson
# Processed data for Washington (WA) - burglary
# Processed data for Washington (WA) - larceny
# Processed data for Washington (WA) - motor-vehicle-theft
# Processed data for Wisconsin (WI) - homicide
# Processed data for Wisconsin (WI) - rape
# Processed data for Wisconsin (WI) - robbery
# Processed data for Wisconsin (WI) - aggravated-assault
# Processed data for Wisconsin (WI) - arson
# Processed data for Wisconsin (WI) - burglary
# Processed data for Wisconsin (WI) - larceny
# Processed data for Wisconsin (WI) - motor-vehicle-theft
# Processed data for West Virginia (WV) - homicide
# Processed data for West Virginia (WV) - rape
# Processed data for West Virginia (WV) - robbery
# Processed data for West Virginia (WV) - aggravated-assault
# Processed data for West Virginia (WV) - arson
# Processed data for West Virginia (WV) - burglary
# Processed data for West Virginia (WV) - larceny
# Processed data for West Virginia (WV) - motor-vehicle-theft
# Processed data for Wyoming (WY) - homicide
# Processed data for Wyoming (WY) - rape
# Processed data for Wyoming (WY) - robbery
# Processed data for Wyoming (WY) - aggravated-assault
# Processed data for Wyoming (WY) - arson
# Processed data for Wyoming (WY) - burglary
# Processed data for Wyoming (WY) - larceny
# Processed data for Wyoming (WY) - motor-vehicle-theft
# All data for homicide saved to '../Resources/State/homicide_state_crime_data.csv'
# All data for rape saved to '../Resources/State/rape_state_crime_data.csv'
# All data for robbery saved to '../Resources/State/robbery_state_crime_data.csv'
# All data for aggravated-assault saved to '../Resources/State/aggravated-assault_state_crime_data.csv'
# All data for arson saved to '../Resources/State/arson_state_crime_data.csv'
# All data for burglary saved to '../Resources/State/burglary_state_crime_data.csv'
# All data for larceny saved to '../Resources/State/larceny_state_crime_data.csv'
# All data for motor-vehicle-theft saved to '../Resources/State/motor-vehicle-theft_state_crime_data.csv'
