# %%
import requests
import pandas as pd
import time
from config import api_key, census_api_key
from pprint import pprint
from census import Census
import censusdata
import re
import numpy
import hvplot.pandas
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="fc4e148a-26e1-4de8-aea9-2f3d46f65973" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"7fd7abb0-bc42-4cab-bf0b-7a653e96adb9":{"version":"3.6.0","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"c92df3cf95b34f71b9abfec2ac608413","client_comm_id":"d78433c694d540bf801ca0689089744d"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1"},{"type":"model","name":"JSComponent1"},{"ty ...
#   var render_items = [{"docid":"7fd7abb0-bc42-4cab-bf0b-7a653e96adb9","roots":{"p1002":"fc4e148a-26e1-4de8-aea9-2f3d46f65973"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
# List of states with their abbreviations
states = {
    "AK": "Alaska", "AL": "Alabama", "AR": "Arkansas", "AZ": "Arizona",
    "CA": "California", "CO": "Colorado", "CT": "Connecticut", "DC": "District of Columbia",
    "DE": "Delaware", "FL": "Florida", "GA": "Georgia", "HI": "Hawaii",
    "IA": "Iowa", "ID": "Idaho", "IL": "Illinois", "IN": "Indiana",
    "KS": "Kansas", "KY": "Kentucky", "LA": "Louisiana", "MA": "Massachusetts",
    "MD": "Maryland", "ME": "Maine", "MI": "Michigan", "MN": "Minnesota",
    "MO": "Missouri", "MS": "Mississippi", "MT": "Montana", "NC": "North Carolina",
    "ND": "North Dakota", "NE": "Nebraska", "NH": "New Hampshire", "NJ": "New Jersey",
    "NM": "New Mexico", "NV": "Nevada", "NY": "New York", "OH": "Ohio",
    "OK": "Oklahoma", "OR": "Oregon", "PA": "Pennsylvania", "RI": "Rhode Island",
    "SC": "South Carolina", "SD": "South Dakota", "TN": "Tennessee", "TX": "Texas",
    "UT": "Utah", "VA": "Virginia", "VT": "Vermont", "WA": "Washington",
    "WI": "Wisconsin", "WV": "West Virginia", "WY": "Wyoming"
}

# Function to fetch agency data from the API
def fetch_agency_data(state_abbr):
    base_url = f'https://api.usa.gov/crime/fbi/cde/agency/byStateAbbr/{state_abbr}'
    response = requests.get(base_url, api_key)
    if response.status_code != 200:
        raise ValueError(f"API call failed for {state_abbr} with status {response.status_code}")
    return response.json()

# List to hold filtered data from all states
all_filtered_data = []

# Iterate over each state and process the data
for state_abbr, state_name in states.items():
    try:
        # Fetch data for the current state
        response = fetch_agency_data(state_abbr)
        
        # Iterate through all counties in the response data
        for county, agencies in response.items():
            for agency in agencies:
                # Filter agencies with `agency_type_name` == "City" and valid coordinates
                if (
                    agency.get('agency_type_name') == 'City' and
                    agency.get('latitude') is not None and
                    agency.get('longitude') is not None
                ):
                    # Append filtered data to the list
                    all_filtered_data.append({
                        'State': state_abbr,
                        'Agency Name': agency.get('agency_name'),
                        'Latitude': agency.get('latitude'),
                        'Longitude': agency.get('longitude'),
                        'ORI': agency.get('ori'),
                    })
        print(f"Processed data for {state_name} ({state_abbr})")
    except Exception as e:
        print(f"Error processing {state_name} ({state_abbr}): {e}")
    
    # Pause to avoid overloading the API
    time.sleep(.2)

# Convert the collected data into a single Pandas DataFrame
df_all_agencies = pd.DataFrame(all_filtered_data)

# Add a new "City" column by removing "Police Department" from the "Agency Name"
df_all_agencies["City"] = (
    df_all_agencies["Agency Name"]
    .str.replace(r"Police Department", "", regex=True)  # Remove "Police Department"
    .str.strip()  # Remove leading/trailing spaces
)

# Save the DataFrame to a CSV file
output_path = "../Resources/Agency/Agency_Data/filtered_city_agencies.csv"
df_all_agencies.to_csv(output_path, index=False)

print(f"All filtered agency data saved to {output_path}")
# Out:
# Processed data for Alaska (AK)
# Processed data for Alabama (AL)
# Processed data for Arkansas (AR)
# Processed data for Arizona (AZ)
# Processed data for California (CA)
# Processed data for Colorado (CO)
# Processed data for Connecticut (CT)
# Processed data for District of Columbia (DC)
# Processed data for Delaware (DE)
# Processed data for Florida (FL)
# Processed data for Georgia (GA)
# Processed data for Hawaii (HI)
# Processed data for Iowa (IA)
# Processed data for Idaho (ID)
# Processed data for Illinois (IL)
# Processed data for Indiana (IN)
# Processed data for Kansas (KS)
# Processed data for Kentucky (KY)
# Processed data for Louisiana (LA)
# Processed data for Massachusetts (MA)
# Processed data for Maryland (MD)
# Processed data for Maine (ME)
# Processed data for Michigan (MI)
# Processed data for Minnesota (MN)
# Processed data for Missouri (MO)
# Processed data for Mississippi (MS)
# Processed data for Montana (MT)
# Processed data for North Carolina (NC)
# Processed data for North Dakota (ND)
# Processed data for Nebraska (NE)
# Processed data for New Hampshire (NH)
# Processed data for New Jersey (NJ)
# Processed data for New Mexico (NM)
# Processed data for Nevada (NV)
# Processed data for New York (NY)
# Processed data for Ohio (OH)
# Processed data for Oklahoma (OK)
# Processed data for Oregon (OR)
# Processed data for Pennsylvania (PA)
# Processed data for Rhode Island (RI)
# Processed data for South Carolina (SC)
# Processed data for South Dakota (SD)
# Processed data for Tennessee (TN)
# Processed data for Texas (TX)
# Processed data for Utah (UT)
# Processed data for Virginia (VA)
# Processed data for Vermont (VT)
# Processed data for Washington (WA)
# Processed data for Wisconsin (WI)
# Processed data for West Virginia (WV)
# Processed data for Wyoming (WY)
# All filtered agency data saved to ../Resources/Agency/Agency_Data/filtered_city_agencies.csv

# %%
df_all_agencies.head()
# Out:
#   State               Agency Name   Latitude   Longitude        ORI    City
# 0    AK    Nome Police Department  64.783686 -164.188912  AK0010600    Nome
# 1    AK   Sitka Police Department  57.052124 -135.334180  AK0010900   Sitka
# 2    AK  Bethel Police Department  60.928916 -160.153350  AK0011300  Bethel
# 3    AK  Haines Police Department  59.098771 -135.576936  AK0012100  Haines
# 4    AK  Juneau Police Department  58.356556 -134.507310  AK0010300  Juneau

# %%
c = Census(census_api_key, year=2021)

# Dictionary mapping state abbreviations to FIPS codes
state_abbr_to_fips = {
    'AL': '01', 'AK': '02', 'AZ': '04', 'AR': '05', 'CA': '06', 'CO': '08', 'CT': '09',
    'DE': '10', 'DC': '11', 'FL': '12', 'GA': '13', 'HI': '15', 'ID': '16', 'IL': '17',
    'IN': '18', 'IA': '19', 'KS': '20', 'KY': '21', 'LA': '22', 'ME': '23', 'MD': '24',
    'MA': '25', 'MI': '26', 'MN': '27', 'MS': '28', 'MO': '29', 'MT': '30', 'NE': '31',
    'NV': '32', 'NH': '33', 'NJ': '34', 'NM': '35', 'NY': '36', 'NC': '37', 'ND': '38',
    'OH': '39', 'OK': '40', 'OR': '41', 'PA': '42', 'RI': '44', 'SC': '45', 'SD': '46',
    'TN': '47', 'TX': '48', 'UT': '49', 'VT': '50', 'VA': '51', 'WA': '53', 'WV': '54',
    'WI': '55', 'WY': '56'
}

def get_poverty_for_city(city_population_data, city_name):
    city_data = city_population_data.get(city_name)
    if city_data:
        poverty = city_data[1]  # Access the second element of the list (poverty data)
    else:
        poverty = None
    return poverty

def calculate_poverty_rate(population, poverty):
    if population == 0 or poverty == 0:
        return None  # or return a specific value to indicate unknown/undefined
    poverty_rate = round((poverty / population) * 100, 2)
    return poverty_rate

# Function to get population data for all cities in a state at once
def get_population_for_state(state_abbr):
    # Convert state abbreviation to FIPS code
    state_fips = state_abbr_to_fips.get(state_abbr)
    if not state_fips:
        raise ValueError(f"Invalid state abbreviation: {state_abbr}")
    
    # Get population data for all cities in the state
    census_data = c.acs5.get(
        (
            "NAME",          # City name
            "B01003_001E",   # Total population
            "B17001_002E"   # Poverty count
        ),
        {'for': 'place:*', 'in': f'state:{state_fips}'}
    )
    
    # Convert to DataFrame
    census_pd = pd.DataFrame(census_data[1:], columns=census_data[0])
    
    # Clean city names by removing unnecessary information
    census_pd['NAME'] = census_pd['NAME'].apply(lambda x: re.sub(r'\(.*?\)', '', x).replace('CDP', '').replace('City', '').strip().split(',')[0].strip())
    
    # Return as a dictionary for easy access (City -> {'Population': ..., 'Poverty': ...})
    return dict(zip(census_pd['NAME'], census_pd[['B01003_001E', 'B17001_002E']].values.tolist()))

# List to store population data for all states
state_population_data = {}

# Iterate over rows in df_all_agencies and append the population data
population_list = []
poverty_list = []
poverty_rate_list = []

# Process one state at a time
for index, row in df_all_agencies.iterrows():
    city = row['City']
    state_abbr = row['State']

    # Check if we've already fetched the population data for this state
    if state_abbr not in state_population_data:
        try:
            # Fetch the population data for the current state
            state_population_data[state_abbr] = get_population_for_state(state_abbr)
            print(f"Fetched population data for {state_abbr}")
        except Exception as e:
            print(f"Error fetching population data for {state_abbr}: {e}")
            state_population_data[state_abbr] = {}  # Empty dict in case of error

    # Retrieve the population for the city (flexible match)
    city_population_data = state_population_data.get(state_abbr, {})
    city_population_data = {key.replace("  ", " "): value 
                           for key, value in state_population_data.get(state_abbr, {}).items()}
    city = city.lower()
    matching_cities = [city_name for city_name in city_population_data 
                     if city.lower() in city_name.lower() 
                     or city_name.lower() in city.lower()]
    if matching_cities:
        population = city_population_data.get(matching_cities[0])[0]
        poverty = get_poverty_for_city(city_population_data, matching_cities[0])
        poverty_rate = calculate_poverty_rate(population, poverty)
    else:
        population = None
        poverty = None
        poverty_rate = None

    population_list.append(population)
    poverty_list.append(poverty)
    poverty_rate_list.append(poverty_rate)

# Add the population and poverty data as new columns in df_all_agencies
df_all_agencies['Population'] = population_list
df_all_agencies['Poverty'] = poverty_list
df_all_agencies['Poverty Rate'] = poverty_rate_list

# Save the final DataFrame with population data to a new CSV file
output_path = "../Resources/Agency/Agency_Data/filtered_city_agencies.csv"
df_all_agencies.to_csv(output_path, index=False)
print(f"Data saved to {output_path}")
# Out:
# Fetched population data for AK
# Fetched population data for AL
# Fetched population data for AR
# Fetched population data for AZ
# Fetched population data for CA
# Fetched population data for CO
# Fetched population data for CT
# Fetched population data for DC
# Fetched population data for DE
# Fetched population data for FL
# Fetched population data for GA
# Fetched population data for HI
# Fetched population data for IA
# Fetched population data for ID
# Fetched population data for IL
# Fetched population data for IN
# Fetched population data for KS
# Fetched population data for KY
# Fetched population data for LA
# Fetched population data for MA
# Fetched population data for MD
# Fetched population data for ME
# Fetched population data for MI
# Fetched population data for MN
# Fetched population data for MO
# Fetched population data for MS
# Fetched population data for MT
# Fetched population data for NC
# Fetched population data for ND
# Fetched population data for NE
# Fetched population data for NH
# Fetched population data for NJ
# Fetched population data for NM
# Fetched population data for NV
# Fetched population data for NY
# Fetched population data for OH
# Fetched population data for OK
# Fetched population data for OR
# Fetched population data for PA
# Fetched population data for RI
# Fetched population data for SC
# Fetched population data for SD
# Fetched population data for TN
# Fetched population data for TX
# Fetched population data for UT
# Fetched population data for VA
# Fetched population data for VT
# Fetched population data for WA
# Fetched population data for WI
# Fetched population data for WV
# Fetched population data for WY
# Data saved to ../Resources/Agency/Agency_Data/filtered_city_agencies.csv

# %%
#Re-reading in the csv to make sure it's cleaned.
df_all_agencies = pd.read_csv("../Resources/Agency/Agency_Data/filtered_city_agencies.csv")

# Get the original number of rows
original_rows = df_all_agencies.shape[0]

# Remove rows with null population values
df_all_agencies = df_all_agencies.dropna(subset=['Population'])

# Get the new number of rows
new_rows = df_all_agencies.shape[0]

# Print the number of nulls dropped
nulls_dropped = original_rows - new_rows
print(f"Dropped {nulls_dropped} rows with null population values from filtered_city_agencies.csv")
output_path = "../Resources/Agency/Agency_Data/filtered_city_agencies.csv"
df_all_agencies.to_csv(output_path, index=False)
# Sort the DataFrame by state and population in descending order
df_sorted = df_all_agencies.sort_values(by=['State', 'Population'], ascending=[True, False])

# Group the DataFrame by state and get the top 25 population cities in each state
df_top_cities = df_sorted.groupby('State').head(25)

# Write the filtered DataFrame to a new CSV file
output_path = "../Resources/Agency/Agency_Data/top_25_state_cities.csv"
df_top_cities.to_csv(output_path, index=False)
print(f"Data saved to {output_path}")

# Get the top 50 cities in the whole country by population
df_top_50_cities = df_sorted.nlargest(50, 'Population')
df_top_1_city = df_sorted.nlargest(1, 'Population')
# Write the top 50 cities to a new CSV file
output_path = "../Resources/Agency/Agency_Data/top_50_US_cities.csv"
df_top_50_cities.to_csv(output_path, index=False)
print(f"Data saved to {output_path}")
output_path = "../Resources/Agency/Agency_Data/testing_cities.csv"
df_top_1_city.to_csv(output_path, index=False)
print(f"Data saved to {output_path}")
# Out:
# Dropped 1154 rows with null population values from filtered_city_agencies.csv
# Data saved to ../Resources/Agency/Agency_Data/top_25_state_cities.csv
# Data saved to ../Resources/Agency/Agency_Data/top_50_US_cities.csv
# Data saved to ../Resources/Agency/Agency_Data/testing_cities.csv

# %%
# Record the start time of the script
start_time = time.time()

# Load the top_cities.csv file
df_top_cities = pd.read_csv("../Resources/Agency/Agency_Data/top_25_state_cities.csv")

# Define the crime types
violent_crimes = ["homicide", "rape", "robbery", "aggravated-assault"]
property_crimes = ["arson", "burglary", "larceny", "motor-vehicle-theft"]
retries = 0

# Define the date range
begin_date = "01-2023"
end_date = "12-2023"
time_frame = f'?from={begin_date}&to={end_date}'

def countdown(t):
    while t:
        mins, secs = divmod(t, 60)
        timer = '{:02d}m {:02d}s'.format(mins, secs)
        print(timer, end="\r")
        time.sleep(30)
        t -= 30

def fetch_crime_data(ori, crime_type):
    base_url = f'https://api.usa.gov/crime/fbi/cde/summarized/agency/{ori}/{crime_type}{time_frame}{api_key}'
    max_retries = 5
    retries = 0

    while retries < max_retries:
        try:
            response = requests.get(base_url)
            time.sleep(2)  # Slow down for lazy API 
            response.raise_for_status()  # Raise an exception for HTTP errors
            return response.json()
        except requests.exceptions.RequestException as e:
            print(f"Error fetching data for {ori}, {crime_type}: {e}")
            retries += 1
            if retries < max_retries:
                print(f"Retrying in 10 minutes... (Attempt {retries}/{max_retries})")
                countdown(600)  # 10 minute countdown
            else:
                print("Max retries exceeded. Giving up.")
                return None

# List to hold processed crime data
crime_data_list = []
total_agencies = len(df_top_cities)
# Process each city in the DataFrame
for iteration, row in df_top_cities.iterrows():
    # Record the start time for this iteration
    iteration_start_time = time.time()
    
    ori = row['ORI']
    agency_name = row['Agency Name']
    population = row['Population']

    # Initialize crime totals
    violent_crime_total = 0
    property_crime_total = 0

    # Fetch and process crime data
    for crime_type in violent_crimes + property_crimes:
        data = fetch_crime_data(ori, crime_type)
        if data and 'offenses' in data:
            # Extract data using the 'Agency Name' as the key
            actuals = data['offenses'].get('actuals', {})
            agency_data = {key: int(value) if isinstance(value, int) else 0 for key, value in actuals.get(agency_name, {}).items()} # Came across sum error 2 hours in to my pull, made sure all values are int, if not return 0.
            total_crimes = sum(agency_data.values())
            
            if crime_type in violent_crimes:
                violent_crime_total += total_crimes
            elif crime_type in property_crimes:
                property_crime_total += total_crimes

    # Calculate crime rate per 100,000 population
    crime_rate = round(((violent_crime_total + property_crime_total) / population) * 100000,2)
    violent_crime_rate = round((violent_crime_total / population) * 100000,2)
    property_crime_rate = round((property_crime_total / population) * 100000,2)
    # Get rid of any redundant decimals
    df_top_cities["Population"] = df_top_cities["Population"].round(0).astype(int)
    df_top_cities["Poverty"] = df_top_cities["Poverty"].round(0).astype(int)
    # Append the calculated data to the list
    crime_data_list.append({
        'ORI': ori,
        'Violent Crime': violent_crime_total,
        'Property Crime': property_crime_total,
        'Violent Crime(Per 100k)': violent_crime_rate,
        'Property Crime(Per 100k)': property_crime_rate,
        'Crime Rate(Per 100k)': crime_rate
    })

    # Calculate elapsed time
    elapsed_time = time.time() - start_time
    elapsed_minutes, elapsed_seconds = divmod(int(elapsed_time), 60)

    # Calculate time taken for this iteration
    iteration_elapsed_time = time.time() - iteration_start_time
    iteration_elapsed_minutes, iteration_elapsed_seconds = divmod(int(iteration_elapsed_time), 60)

    # Calculate estimated time remaining.
    estimated_remaining = iteration_elapsed_seconds * (total_agencies - (iteration + 1))
    remaining_minutes, remaining_seconds = divmod(estimated_remaining, 60)
    formatted_remaining_time = f"{remaining_minutes}m {remaining_seconds}s"

    # Spent some time showing time data so that I can see how long it's going to take and where exactly it's getting stuck if it doesn't succeed.
    print(f"Processed data for {agency_name}, {row["State"]} - This Process: {iteration_elapsed_seconds:.2f}s ({iteration + 1}/{total_agencies}) - {elapsed_minutes}m {elapsed_seconds}s - Est Remaining: {remaining_minutes}m {remaining_seconds}s {'Retries: ' + str(retries) if retries != 0 else ''}")

# Create a DataFrame from the crime data list
df_crime_data = pd.DataFrame(crime_data_list)

# Merge the crime data with the original DataFrame
df_merged = pd.merge(df_top_cities, df_crime_data, on='ORI')

# Save the merged DataFrame to a new CSV file
output_path = "../Resources/Agency/top_25_state_cities_crime_data.csv"
df_merged.to_csv(output_path, index=False)
print(f"Data saved to {output_path}")
# Out:
# Processed data for Anchorage Police Department, AK - This Process: 23.00s (1/1204) - 0m 23s - Est Remaining: 461m 9s
# Processed data for Fairbanks Police Department, AK - This Process: 23.00s (2/1204) - 0m 47s - Est Remaining: 460m 46s
# Processed data for Juneau Police Department, AK - This Process: 23.00s (3/1204) - 1m 11s - Est Remaining: 460m 23s
# Processed data for Wasilla Police Department, AK - This Process: 23.00s (4/1204) - 1m 34s - Est Remaining: 460m 0s
# Processed data for Sitka Police Department, AK - This Process: 22.00s (5/1204) - 1m 57s - Est Remaining: 439m 38s
# Processed data for Ketchikan Police Department, AK - This Process: 21.00s (6/1204) - 2m 18s - Est Remaining: 419m 18s
# Processed data for Kenai Police Department, AK - This Process: 22.00s (7/1204) - 2m 41s - Est Remaining: 438m 54s
# Processed data for Bethel Police Department, AK - This Process: 21.00s (8/1204) - 3m 3s - Est Remaining: 418m 36s
# Processed data for Palmer Police Department, AK - This Process: 22.00s (9/1204) - 3m 26s - Est Remaining: 438m 10s
# Processed data for Kodiak Police Department, AK - This Process: 22.00s (10/1204) - 3m 48s - Est Remaining: 437m 48s
# Processed data for Homer Police Department, AK - This Process: 24.00s (11/1204) - 4m 12s - Est Remaining: 477m 12s
# Processed data for Soldotna Police Department, AK - This Process: 22.00s (12/1204) - 4m 35s - Est Remaining: 437m 4s
# Processed data for Unalaska Police Department, AK - This Process: 22.00s (13/1204) - 4m 58s - Est Remaining: 436m 42s
# Processed data for Valdez Police Department, AK - This Process: 23.00s (14/1204) - 5m 22s - Est Remaining: 456m 10s
# Processed data for Nome Police Department, AK - This Process: 23.00s (15/1204) - 5m 45s - Est Remaining: 455m 47s
# Processed data for Petersburg Police Department, AK - This Process: 23.00s (16/1204) - 6m 8s - Est Remaining: 455m 24s
# Processed data for Kotzebue Police Department, AK - This Process: 22.00s (17/1204) - 6m 30s - Est Remaining: 435m 14s
# Processed data for North Pole Police Department, AK - This Process: 22.00s (18/1204) - 6m 53s - Est Remaining: 434m 52s
# Processed data for Seward Police Department, AK - This Process: 22.00s (19/1204) - 7m 16s - Est Remaining: 434m 30s
# Processed data for Cordova Police Department, AK - This Process: 22.00s (20/1204) - 7m 38s - Est Remaining: 434m 8s
# Processed data for Wrangell Police Department, AK - This Process: 22.00s (21/1204) - 8m 1s - Est Remaining: 433m 46s
# Processed data for Dillingham Police Department, AK - This Process: 22.00s (22/1204) - 8m 23s - Est Remaining: 433m 24s
# Processed data for Haines Police Department, AK - This Process: 22.00s (23/1204) - 8m 46s - Est Remaining: 433m 2s
# Processed data for Skagway Police Department, AK - This Process: 22.00s (24/1204) - 9m 8s - Est Remaining: 432m 40s
# Processed data for Sand Point Police Department, AK - This Process: 22.00s (25/1204) - 9m 30s - Est Remaining: 432m 18s
# Processed data for Huntsville Police Department, AL - This Process: 21.00s (26/1204) - 9m 52s - Est Remaining: 412m 18s
# Processed data for Birmingham Police Department, AL - This Process: 22.00s (27/1204) - 10m 14s - Est Remaining: 431m 34s
# Processed data for Montgomery Police Department, AL - This Process: 24.00s (28/1204) - 10m 38s - Est Remaining: 470m 24s
# Processed data for Mobile Police Department, AL - This Process: 22.00s (29/1204) - 11m 1s - Est Remaining: 430m 50s
# Processed data for Tuscaloosa Police Department, AL - This Process: 23.00s (30/1204) - 11m 24s - Est Remaining: 450m 2s
# Processed data for Hoover Police Department, AL - This Process: 22.00s (31/1204) - 11m 47s - Est Remaining: 430m 6s
# Processed data for Auburn Police Department, AL - This Process: 22.00s (32/1204) - 12m 9s - Est Remaining: 429m 44s
# Processed data for Dothan Police Department, AL - This Process: 21.00s (33/1204) - 12m 31s - Est Remaining: 409m 51s
# Processed data for Decatur Police Department, AL - This Process: 22.00s (34/1204) - 12m 53s - Est Remaining: 429m 0s
# Processed data for Madison Police Department, AL - This Process: 22.00s (35/1204) - 13m 16s - Est Remaining: 428m 38s
# Processed data for Florence Police Department, AL - This Process: 23.00s (36/1204) - 13m 39s - Est Remaining: 447m 44s
# Processed data for Vestavia Hills Police Department, AL - This Process: 23.00s (37/1204) - 14m 3s - Est Remaining: 447m 21s
# Processed data for Phenix City Police Department, AL - This Process: 21.00s (38/1204) - 14m 25s - Est Remaining: 408m 6s
# Processed data for Prattville Police Department, AL - This Process: 21.00s (39/1204) - 14m 46s - Est Remaining: 407m 45s
# Processed data for Gadsden Police Department, AL - This Process: 21.00s (40/1204) - 15m 8s - Est Remaining: 407m 24s
# Processed data for Alabaster Police Department, AL - This Process: 22.00s (41/1204) - 15m 30s - Est Remaining: 426m 26s
# Processed data for Opelika Police Department, AL - This Process: 22.00s (42/1204) - 15m 53s - Est Remaining: 426m 4s
# Processed data for Northport Police Department, AL - This Process: 22.00s (43/1204) - 16m 16s - Est Remaining: 425m 42s
# Processed data for Enterprise Police Department, AL - This Process: 21.00s (44/1204) - 16m 38s - Est Remaining: 406m 0s
# Processed data for Daphne Police Department, AL - This Process: 22.00s (45/1204) - 17m 0s - Est Remaining: 424m 58s
# Processed data for Homewood Police Department, AL - This Process: 22.00s (46/1204) - 17m 23s - Est Remaining: 424m 36s
# Processed data for Bessemer Police Department, AL - This Process: 23.00s (47/1204) - 17m 46s - Est Remaining: 443m 31s
# Processed data for Athens Police Department, AL - This Process: 22.00s (48/1204) - 18m 9s - Est Remaining: 423m 52s
# Processed data for Trussville Police Department, AL - This Process: 22.00s (49/1204) - 18m 31s - Est Remaining: 423m 30s
# Processed data for Pelham Police Department, AL - This Process: 22.00s (50/1204) - 18m 54s - Est Remaining: 423m 8s
# Processed data for Little Rock Police Department, AR - This Process: 22.00s (51/1204) - 19m 16s - Est Remaining: 422m 46s
# Processed data for Fayetteville Police Department, AR - This Process: 22.00s (52/1204) - 19m 39s - Est Remaining: 422m 24s
# Processed data for Fort Smith Police Department, AR - This Process: 22.00s (53/1204) - 20m 1s - Est Remaining: 422m 2s
# Processed data for Springdale Police Department, AR - This Process: 22.00s (54/1204) - 20m 23s - Est Remaining: 421m 40s
# Processed data for Jonesboro Police Department, AR - This Process: 22.00s (55/1204) - 20m 46s - Est Remaining: 421m 18s
# Processed data for Rogers Police Department, AR - This Process: 22.00s (56/1204) - 21m 9s - Est Remaining: 420m 56s
# Processed data for North Little Rock Police Department, AR - This Process: 22.00s (57/1204) - 21m 31s - Est Remaining: 420m 34s
# Processed data for Conway Police Department, AR - This Process: 22.00s (58/1204) - 21m 54s - Est Remaining: 420m 12s
# Processed data for Bentonville Police Department, AR - This Process: 22.00s (59/1204) - 22m 16s - Est Remaining: 419m 50s
# Processed data for Pine Bluff Police Department, AR - This Process: 22.00s (60/1204) - 22m 39s - Est Remaining: 419m 28s
# Processed data for Hot Springs Police Department, AR - This Process: 22.00s (61/1204) - 23m 1s - Est Remaining: 419m 6s
# Processed data for Benton Police Department, AR - This Process: 22.00s (62/1204) - 23m 24s - Est Remaining: 418m 44s
# Processed data for Sherwood Police Department, AR - This Process: 23.00s (63/1204) - 23m 47s - Est Remaining: 437m 23s
# Processed data for Bella Vista Police Department, AR - This Process: 23.00s (64/1204) - 24m 10s - Est Remaining: 437m 0s
# Processed data for Texarkana Police Department, AR - This Process: 22.00s (65/1204) - 24m 33s - Est Remaining: 417m 38s
# Processed data for Jacksonville Police Department, AR - This Process: 22.00s (66/1204) - 24m 55s - Est Remaining: 417m 16s
# Processed data for Paragould Police Department, AR - This Process: 22.00s (67/1204) - 25m 17s - Est Remaining: 416m 54s
# Processed data for Russellville Police Department, AR - This Process: 22.00s (68/1204) - 25m 40s - Est Remaining: 416m 32s
# Processed data for Cabot Police Department, AR - This Process: 22.00s (69/1204) - 26m 3s - Est Remaining: 416m 10s
# Processed data for West Memphis Police Department, AR - This Process: 22.00s (70/1204) - 26m 25s - Est Remaining: 415m 48s
# Processed data for Van Buren Police Department, AR - This Process: 22.00s (71/1204) - 26m 48s - Est Remaining: 415m 26s
# Processed data for Searcy Police Department, AR - This Process: 22.00s (72/1204) - 27m 10s - Est Remaining: 415m 4s
# Processed data for Bryant Police Department, AR - This Process: 22.00s (73/1204) - 27m 32s - Est Remaining: 414m 42s
# Processed data for Maumelle Police Department, AR - This Process: 21.00s (74/1204) - 27m 54s - Est Remaining: 395m 30s
# Processed data for Centerton Police Department, AR - This Process: 23.00s (75/1204) - 28m 17s - Est Remaining: 432m 47s
# Processed data for Phoenix Police Department, AZ - This Process: 23.00s (76/1204) - 28m 40s - Est Remaining: 432m 24s
# Processed data for Chandler Police Department, AZ - This Process: 22.00s (77/1204) - 29m 3s - Est Remaining: 413m 14s
# Processed data for Gilbert Police Department, AZ - This Process: 21.00s (78/1204) - 29m 25s - Est Remaining: 394m 6s
# Processed data for Glendale Police Department, AZ - This Process: 22.00s (79/1204) - 29m 48s - Est Remaining: 412m 30s
# Processed data for Scottsdale Police Department, AZ - This Process: 22.00s (80/1204) - 30m 10s - Est Remaining: 412m 8s
# Processed data for Peoria Police Department, AZ - This Process: 23.00s (81/1204) - 30m 33s - Est Remaining: 430m 29s
# Processed data for Tempe Police Department, AZ - This Process: 21.00s (82/1204) - 30m 55s - Est Remaining: 392m 42s
# Processed data for Surprise Police Department, AZ - This Process: 21.00s (83/1204) - 31m 17s - Est Remaining: 392m 21s
# Processed data for Yuma Police Department, AZ - This Process: 21.00s (84/1204) - 31m 38s - Est Remaining: 392m 0s
# Processed data for Goodyear Police Department, AZ - This Process: 22.00s (85/1204) - 32m 0s - Est Remaining: 410m 18s
# Processed data for Buckeye Police Department, AZ - This Process: 23.00s (86/1204) - 32m 23s - Est Remaining: 428m 34s
# Processed data for Avondale Police Department, AZ - This Process: 22.00s (87/1204) - 32m 46s - Est Remaining: 409m 34s
# Processed data for Flagstaff Police Department, AZ - This Process: 22.00s (88/1204) - 33m 8s - Est Remaining: 409m 12s
# Processed data for Maricopa Police Department, AZ - This Process: 22.00s (89/1204) - 33m 31s - Est Remaining: 408m 50s
# Processed data for Lake Havasu City Police Department, AZ - This Process: 22.00s (90/1204) - 33m 53s - Est Remaining: 408m 28s
# Processed data for Casa Grande Police Department, AZ - This Process: 23.00s (91/1204) - 34m 17s - Est Remaining: 426m 39s
# Processed data for Marana Police Department, AZ - This Process: 23.00s (92/1204) - 34m 40s - Est Remaining: 426m 16s
# Processed data for Oro Valley Police Department, AZ - This Process: 22.00s (93/1204) - 35m 2s - Est Remaining: 407m 22s
# Processed data for Prescott Valley Police Department, AZ - This Process: 21.00s (94/1204) - 35m 24s - Est Remaining: 388m 30s
# Processed data for Prescott Police Department, AZ - This Process: 22.00s (95/1204) - 35m 47s - Est Remaining: 406m 38s
# Processed data for Sierra Vista Police Department, AZ - This Process: 22.00s (96/1204) - 36m 9s - Est Remaining: 406m 16s
# Processed data for Bullhead City Police Department, AZ - This Process: 23.00s (97/1204) - 36m 33s - Est Remaining: 424m 21s
# Processed data for Apache Junction Police Department, AZ - This Process: 22.00s (98/1204) - 36m 55s - Est Remaining: 405m 32s
# Processed data for El Mirage Police Department, AZ - This Process: 22.00s (99/1204) - 37m 18s - Est Remaining: 405m 10s
# Processed data for San Luis Police Department, AZ - This Process: 22.00s (100/1204) - 37m 40s - Est Remaining: 404m 48s
# Processed data for San Jose Police Department, CA - This Process: 21.00s (101/1204) - 38m 2s - Est Remaining: 386m 3s
# Processed data for San Francisco Police Department, CA - This Process: 22.00s (102/1204) - 38m 24s - Est Remaining: 404m 4s
# Processed data for Fresno Police Department, CA - This Process: 22.00s (103/1204) - 38m 46s - Est Remaining: 403m 42s
# Processed data for Sacramento Police Department, CA - This Process: 21.00s (104/1204) - 39m 8s - Est Remaining: 385m 0s
# Processed data for Long Beach Police Department, CA - This Process: 23.00s (105/1204) - 39m 31s - Est Remaining: 421m 17s
# Processed data for Oakland Police Department, CA - This Process: 22.00s (106/1204) - 39m 54s - Est Remaining: 402m 36s
# Processed data for Anaheim Police Department, CA - This Process: 21.00s (107/1204) - 40m 15s - Est Remaining: 383m 57s
# Processed data for Stockton Police Department, CA - This Process: 22.00s (108/1204) - 40m 38s - Est Remaining: 401m 52s
# Processed data for Santa Ana Police Department, CA - This Process: 22.00s (109/1204) - 41m 0s - Est Remaining: 401m 30s
# Processed data for Irvine Police Department, CA - This Process: 22.00s (110/1204) - 41m 23s - Est Remaining: 401m 8s
# Processed data for Chula Vista Police Department, CA - This Process: 23.00s (111/1204) - 41m 46s - Est Remaining: 418m 59s
# Processed data for Fremont Police Department, CA - This Process: 21.00s (112/1204) - 42m 8s - Est Remaining: 382m 12s
# Processed data for Santa Clarita Police Department, CA - This Process: 21.00s (113/1204) - 42m 29s - Est Remaining: 381m 51s
# Processed data for San Bernardino Police Department, CA - This Process: 21.00s (114/1204) - 42m 51s - Est Remaining: 381m 30s
# Processed data for Modesto Police Department, CA - This Process: 22.00s (115/1204) - 43m 13s - Est Remaining: 399m 18s
# Processed data for Fontana Police Department, CA - This Process: 22.00s (116/1204) - 43m 36s - Est Remaining: 398m 56s
# Processed data for Oxnard Police Department, CA - This Process: 22.00s (117/1204) - 43m 59s - Est Remaining: 398m 34s
# Processed data for Huntington Beach Police Department, CA - This Process: 22.00s (118/1204) - 44m 21s - Est Remaining: 398m 12s
# Processed data for Glendale Police Department, CA - This Process: 22.00s (119/1204) - 44m 43s - Est Remaining: 397m 50s
# Processed data for Santa Rosa Police Department, CA - This Process: 21.00s (120/1204) - 45m 5s - Est Remaining: 379m 24s
# Processed data for Elk Grove Police Department, CA - This Process: 23.00s (121/1204) - 45m 28s - Est Remaining: 415m 9s
# Processed data for Ontario Police Department, CA - This Process: 21.00s (122/1204) - 45m 50s - Est Remaining: 378m 42s
# Processed data for Oceanside Police Department, CA - This Process: 21.00s (123/1204) - 46m 12s - Est Remaining: 378m 21s
# Processed data for Rancho Cucamonga Police Department, CA - This Process: 22.00s (124/1204) - 46m 35s - Est Remaining: 396m 0s
# Processed data for Garden Grove Police Department, CA - This Process: 22.00s (125/1204) - 46m 57s - Est Remaining: 395m 38s
# Processed data for Denver Police Department, CO - This Process: 22.00s (126/1204) - 47m 20s - Est Remaining: 395m 16s
# Processed data for Aurora Police Department, CO - This Process: 22.00s (127/1204) - 47m 42s - Est Remaining: 394m 54s
# Processed data for Fort Collins Police Department, CO - This Process: 22.00s (128/1204) - 48m 5s - Est Remaining: 394m 32s
# Processed data for Lakewood Police Department, CO - This Process: 21.00s (129/1204) - 48m 27s - Est Remaining: 376m 15s
# Processed data for Thornton Police Department, CO - This Process: 22.00s (130/1204) - 48m 49s - Est Remaining: 393m 48s
# Processed data for Arvada Police Department, CO - This Process: 22.00s (131/1204) - 49m 12s - Est Remaining: 393m 26s
# Processed data for Westminster Police Department, CO - This Process: 22.00s (132/1204) - 49m 35s - Est Remaining: 393m 4s
# Processed data for Pueblo Police Department, CO - This Process: 22.00s (133/1204) - 49m 57s - Est Remaining: 392m 42s
# Processed data for Centennial Police Department, CO - This Process: 22.00s (134/1204) - 50m 19s - Est Remaining: 392m 20s
# Processed data for Greeley Police Department, CO - This Process: 22.00s (135/1204) - 50m 42s - Est Remaining: 391m 58s
# Processed data for Boulder Police Department, CO - This Process: 22.00s (136/1204) - 51m 4s - Est Remaining: 391m 36s
# Processed data for Longmont Police Department, CO - This Process: 22.00s (137/1204) - 51m 26s - Est Remaining: 391m 14s
# Processed data for Loveland Police Department, CO - This Process: 22.00s (138/1204) - 51m 49s - Est Remaining: 390m 52s
# Processed data for Broomfield Police Department, CO - This Process: 23.00s (139/1204) - 52m 12s - Est Remaining: 408m 15s
# Processed data for Castle Rock Police Department, CO - This Process: 21.00s (140/1204) - 52m 34s - Est Remaining: 372m 24s
# Processed data for Grand Junction Police Department, CO - This Process: 22.00s (141/1204) - 52m 57s - Est Remaining: 389m 46s
# Processed data for Commerce City Police Department, CO - This Process: 22.00s (142/1204) - 53m 19s - Est Remaining: 389m 24s
# Processed data for Parker Police Department, CO - This Process: 23.00s (143/1204) - 53m 43s - Est Remaining: 406m 43s
# Processed data for Littleton Police Department, CO - This Process: 22.00s (144/1204) - 54m 5s - Est Remaining: 388m 40s
# Processed data for Brighton Police Department, CO - This Process: 22.00s (145/1204) - 54m 27s - Est Remaining: 388m 18s
# Processed data for Northglenn Police Department, CO - This Process: 21.00s (146/1204) - 54m 49s - Est Remaining: 370m 18s
# Processed data for Englewood Police Department, CO - This Process: 22.00s (147/1204) - 55m 12s - Est Remaining: 387m 34s
# Processed data for Wheat Ridge Police Department, CO - This Process: 22.00s (148/1204) - 55m 34s - Est Remaining: 387m 12s
# Processed data for Windsor Police Department, CO - This Process: 23.00s (149/1204) - 55m 57s - Est Remaining: 404m 25s
# Processed data for Lafayette Police Department, CO - This Process: 22.00s (150/1204) - 56m 20s - Est Remaining: 386m 28s
# Processed data for Bridgeport Police Department, CT - This Process: 22.00s (151/1204) - 56m 43s - Est Remaining: 386m 6s
# Processed data for Stamford Police Department, CT - This Process: 22.00s (152/1204) - 57m 5s - Est Remaining: 385m 44s
# Processed data for New Haven Police Department, CT - This Process: 21.00s (153/1204) - 57m 27s - Est Remaining: 367m 51s
# Processed data for Waterbury Police Department, CT - This Process: 21.00s (154/1204) - 57m 48s - Est Remaining: 367m 30s
# Processed data for Norwalk Police Department, CT - This Process: 21.00s (155/1204) - 58m 10s - Est Remaining: 367m 9s
# Processed data for Danbury Police Department, CT - This Process: 22.00s (156/1204) - 58m 32s - Est Remaining: 384m 16s
# Processed data for New Britain Police Department, CT - This Process: 22.00s (157/1204) - 58m 54s - Est Remaining: 383m 54s
# Processed data for West Hartford Police Department, CT - This Process: 22.00s (158/1204) - 59m 17s - Est Remaining: 383m 32s
# Processed data for Meriden Police Department, CT - This Process: 23.00s (159/1204) - 59m 40s - Est Remaining: 400m 35s
# Processed data for Bristol Police Department, CT - This Process: 22.00s (160/1204) - 60m 2s - Est Remaining: 382m 48s
# Processed data for West Haven Police Department, CT - This Process: 21.00s (161/1204) - 60m 24s - Est Remaining: 365m 3s
# Processed data for Hartford Police Department, CT - This Process: 21.00s (162/1204) - 60m 46s - Est Remaining: 364m 42s
# Processed data for East Hartford Police Department, CT - This Process: 23.00s (163/1204) - 61m 9s - Est Remaining: 399m 3s
# Processed data for Milford Police Department, CT - This Process: 22.00s (164/1204) - 61m 32s - Est Remaining: 381m 20s
# Processed data for Middletown Police Department, CT - This Process: 22.00s (165/1204) - 61m 54s - Est Remaining: 380m 58s
# Processed data for Shelton Police Department, CT - This Process: 21.00s (166/1204) - 62m 16s - Est Remaining: 363m 18s
# Processed data for Norwich Police Department, CT - This Process: 21.00s (167/1204) - 62m 38s - Est Remaining: 362m 57s
# Processed data for Manchester Police Department, CT - This Process: 22.00s (168/1204) - 63m 1s - Est Remaining: 379m 52s
# Processed data for Torrington Police Department, CT - This Process: 22.00s (169/1204) - 63m 23s - Est Remaining: 379m 30s
# Processed data for Naugatuck Police Department, CT - This Process: 22.00s (170/1204) - 63m 46s - Est Remaining: 379m 8s
# Processed data for Newington Police Department, CT - This Process: 23.00s (171/1204) - 64m 10s - Est Remaining: 395m 59s
# Processed data for East Haven Police Department, CT - This Process: 22.00s (172/1204) - 64m 32s - Est Remaining: 378m 24s
# Processed data for New London Police Department, CT - This Process: 22.00s (173/1204) - 64m 54s - Est Remaining: 378m 2s
# Processed data for Wethersfield Police Department, CT - This Process: 23.00s (174/1204) - 65m 18s - Est Remaining: 394m 50s
# Processed data for North Haven Police Department, CT - This Process: 22.00s (175/1204) - 65m 40s - Est Remaining: 377m 18s
# Processed data for Wilmington Police Department, DE - This Process: 23.00s (176/1204) - 66m 3s - Est Remaining: 394m 4s
# Processed data for Dover Police Department, DE - This Process: 22.00s (177/1204) - 66m 26s - Est Remaining: 376m 34s
# Processed data for Newark Police Department, DE - This Process: 23.00s (178/1204) - 66m 49s - Est Remaining: 393m 18s
# Processed data for Middletown Police Department, DE - This Process: 22.00s (179/1204) - 67m 12s - Est Remaining: 375m 50s
# Processed data for Smyrna Police Department, DE - This Process: 23.00s (180/1204) - 67m 35s - Est Remaining: 392m 32s
# Processed data for Milford Police Department, DE - This Process: 22.00s (181/1204) - 67m 57s - Est Remaining: 375m 6s
# Processed data for Seaford Police Department, DE - This Process: 24.00s (182/1204) - 68m 21s - Est Remaining: 408m 48s
# Processed data for Georgetown Police Department, DE - This Process: 22.00s (183/1204) - 68m 43s - Est Remaining: 374m 22s
# Processed data for Millsboro Police Department, DE - This Process: 22.00s (184/1204) - 69m 6s - Est Remaining: 374m 0s
# Processed data for Elsmere Police Department, DE - This Process: 22.00s (185/1204) - 69m 28s - Est Remaining: 373m 38s
# Processed data for New Castle Police Department, DE - This Process: 23.00s (186/1204) - 69m 51s - Est Remaining: 390m 14s
# Processed data for Laurel Police Department, DE - This Process: 22.00s (187/1204) - 70m 14s - Est Remaining: 372m 54s
# Processed data for Clayton Police Department, DE - This Process: 22.00s (188/1204) - 70m 36s - Est Remaining: 372m 32s
# Processed data for Camden Police Department, DE - This Process: 23.00s (189/1204) - 70m 59s - Est Remaining: 389m 5s
# Processed data for Harrington Police Department, DE - This Process: 22.00s (190/1204) - 71m 21s - Est Remaining: 371m 48s
# Processed data for Lewes Police Department, DE - This Process: 22.00s (191/1204) - 71m 43s - Est Remaining: 371m 26s
# Processed data for Milton Police Department, DE - This Process: 22.00s (192/1204) - 72m 6s - Est Remaining: 371m 4s
# Processed data for Selbyville Police Department, DE - This Process: 22.00s (193/1204) - 72m 29s - Est Remaining: 370m 42s
# Processed data for Ocean View Police Department, DE - This Process: 23.00s (194/1204) - 72m 52s - Est Remaining: 387m 10s
# Processed data for Bridgeville Police Department, DE - This Process: 23.00s (195/1204) - 73m 16s - Est Remaining: 386m 47s
# Processed data for Delmar Police Department, DE - This Process: 22.00s (196/1204) - 73m 38s - Est Remaining: 369m 36s
# Processed data for Delaware City Police Department, DE - This Process: 22.00s (197/1204) - 74m 0s - Est Remaining: 369m 14s
# Processed data for Cheswold Police Department, DE - This Process: 22.00s (198/1204) - 74m 23s - Est Remaining: 368m 52s
# Processed data for Wyoming Police Department, DE - This Process: 21.00s (199/1204) - 74m 44s - Est Remaining: 351m 45s
# Processed data for Greenwood Police Department, DE - This Process: 22.00s (200/1204) - 75m 6s - Est Remaining: 368m 8s
# Processed data for Miami Police Department, FL - This Process: 22.00s (201/1204) - 75m 28s - Est Remaining: 367m 46s
# Processed data for Tampa Police Department, FL - This Process: 21.00s (202/1204) - 75m 50s - Est Remaining: 350m 42s
# Processed data for Orlando Police Department, FL - This Process: 23.00s (203/1204) - 76m 14s - Est Remaining: 383m 43s
# Processed data for St. Petersburg Police Department, FL - This Process: 22.00s (204/1204) - 76m 36s - Est Remaining: 366m 40s
# Processed data for Hialeah Police Department, FL - This Process: 22.00s (205/1204) - 76m 58s - Est Remaining: 366m 18s
# Processed data for Port St. Lucie Police Department, FL - This Process: 22.00s (206/1204) - 77m 21s - Est Remaining: 365m 56s
# Processed data for Tallahassee Police Department, FL - This Process: 22.00s (207/1204) - 77m 43s - Est Remaining: 365m 34s
# Processed data for Cape Coral Police Department, FL - This Process: 22.00s (208/1204) - 78m 5s - Est Remaining: 365m 12s
# Processed data for Fort Lauderdale Police Department, FL - This Process: 22.00s (209/1204) - 78m 27s - Est Remaining: 364m 50s
# Processed data for Pembroke Pines Police Department, FL - This Process: 22.00s (210/1204) - 78m 49s - Est Remaining: 364m 28s
# Processed data for Hollywood Police Department, FL - This Process: 21.00s (211/1204) - 79m 11s - Est Remaining: 347m 33s
# Processed data for Gainesville Police Department, FL - This Process: 22.00s (212/1204) - 79m 34s - Est Remaining: 363m 44s
# Processed data for Miramar Police Department, FL - This Process: 22.00s (213/1204) - 79m 56s - Est Remaining: 363m 22s
# Processed data for Coral Springs Police Department, FL - This Process: 22.00s (214/1204) - 80m 19s - Est Remaining: 363m 0s
# Processed data for Palm Bay Police Department, FL - This Process: 22.00s (215/1204) - 80m 42s - Est Remaining: 362m 38s
# Processed data for Clearwater Police Department, FL - This Process: 22.00s (216/1204) - 81m 5s - Est Remaining: 362m 16s
# Processed data for Miami Gardens Police Department, FL - This Process: 23.00s (217/1204) - 81m 28s - Est Remaining: 378m 21s
# Processed data for Pompano Beach Police Department, FL - This Process: 22.00s (218/1204) - 81m 50s - Est Remaining: 361m 32s
# Processed data for Lakeland Police Department, FL - This Process: 23.00s (219/1204) - 82m 14s - Est Remaining: 377m 35s
# Processed data for Davie Police Department, FL - This Process: 22.00s (220/1204) - 82m 36s - Est Remaining: 360m 48s
# Processed data for Sunrise Police Department, FL - This Process: 22.00s (221/1204) - 82m 58s - Est Remaining: 360m 26s
# Processed data for Boca Raton Police Department, FL - This Process: 22.00s (222/1204) - 83m 21s - Est Remaining: 360m 4s
# Processed data for Deerfield Beach Police Department, FL - This Process: 23.00s (223/1204) - 83m 44s - Est Remaining: 376m 3s
# Processed data for Fort Myers Police Department, FL - This Process: 21.00s (224/1204) - 84m 6s - Est Remaining: 343m 0s
# Processed data for Melbourne Police Department, FL - This Process: 22.00s (225/1204) - 84m 28s - Est Remaining: 358m 58s
# Processed data for Atlanta Police Department, GA - This Process: 22.00s (226/1204) - 84m 51s - Est Remaining: 358m 36s
# Processed data for Columbus Police Department, GA - This Process: 22.00s (227/1204) - 85m 13s - Est Remaining: 358m 14s
# Processed data for Athens-Clarke County Police Department, GA - This Process: 21.00s (228/1204) - 85m 35s - Est Remaining: 341m 36s
# Processed data for Sandy Springs Police Department, GA - This Process: 22.00s (229/1204) - 85m 58s - Est Remaining: 357m 30s
# Processed data for Roswell Police Department, GA - This Process: 22.00s (230/1204) - 86m 21s - Est Remaining: 357m 8s
# Processed data for Johns Creek Police Department, GA - This Process: 22.00s (231/1204) - 86m 43s - Est Remaining: 356m 46s
# Processed data for Warner Robins Police Department, GA - This Process: 21.00s (232/1204) - 87m 5s - Est Remaining: 340m 12s
# Processed data for Albany Police Department, GA - This Process: 21.00s (233/1204) - 87m 27s - Est Remaining: 339m 51s
# Processed data for Alpharetta Police Department, GA - This Process: 22.00s (234/1204) - 87m 49s - Est Remaining: 355m 40s
# Processed data for Marietta Police Department, GA - This Process: 22.00s (235/1204) - 88m 11s - Est Remaining: 355m 18s
# Processed data for Smyrna Police Department, GA - This Process: 22.00s (236/1204) - 88m 33s - Est Remaining: 354m 56s
# Processed data for Valdosta Police Department, GA - This Process: 22.00s (237/1204) - 88m 56s - Est Remaining: 354m 34s
# Processed data for Dunwoody  Police Department, GA - This Process: 22.00s (238/1204) - 89m 19s - Est Remaining: 354m 12s
# Processed data for Gainesville Police Department, GA - This Process: 23.00s (239/1204) - 89m 42s - Est Remaining: 369m 55s
# Processed data for East Point Police Department, GA - This Process: 22.00s (240/1204) - 90m 4s - Est Remaining: 353m 28s
# Processed data for Peachtree City Police Department, GA - This Process: 22.00s (241/1204) - 90m 27s - Est Remaining: 353m 6s
# Processed data for Rome Police Department, GA - This Process: 22.00s (242/1204) - 90m 49s - Est Remaining: 352m 44s
# Processed data for Hinesville Police Department, GA - This Process: 21.00s (243/1204) - 91m 11s - Est Remaining: 336m 21s
# Processed data for Douglasville Police Department, GA - This Process: 21.00s (244/1204) - 91m 32s - Est Remaining: 336m 0s
# Processed data for Dalton Police Department, GA - This Process: 22.00s (245/1204) - 91m 55s - Est Remaining: 351m 38s
# Processed data for Woodstock Police Department, GA - This Process: 23.00s (246/1204) - 92m 18s - Est Remaining: 367m 14s
# Processed data for Kennesaw Police Department, GA - This Process: 22.00s (247/1204) - 92m 40s - Est Remaining: 350m 54s
# Processed data for Statesboro Police Department, GA - This Process: 22.00s (248/1204) - 93m 2s - Est Remaining: 350m 32s
# Processed data for Canton Police Department, GA - This Process: 21.00s (249/1204) - 93m 24s - Est Remaining: 334m 15s
# Processed data for Duluth Police Department, GA - This Process: 22.00s (250/1204) - 93m 46s - Est Remaining: 349m 48s
# Processed data for Honolulu Police Department, HI - This Process: 22.00s (251/1204) - 94m 9s - Est Remaining: 349m 26s
# Processed data for Des Moines Police Department, IA - This Process: 22.00s (252/1204) - 94m 32s - Est Remaining: 349m 4s
# Processed data for Cedar Rapids Police Department, IA - This Process: 22.00s (253/1204) - 94m 54s - Est Remaining: 348m 42s
# Processed data for Davenport Police Department, IA - This Process: 22.00s (254/1204) - 95m 16s - Est Remaining: 348m 20s
# Processed data for Iowa City Police Department, IA - This Process: 22.00s (255/1204) - 95m 39s - Est Remaining: 347m 58s
# Processed data for Waterloo Police Department, IA - This Process: 22.00s (256/1204) - 96m 1s - Est Remaining: 347m 36s
# Processed data for West Des Moines Police Department, IA - This Process: 22.00s (257/1204) - 96m 24s - Est Remaining: 347m 14s
# Processed data for Ankeny Police Department, IA - This Process: 23.00s (258/1204) - 96m 47s - Est Remaining: 362m 38s
# Processed data for Ames Police Department, IA - This Process: 22.00s (259/1204) - 97m 10s - Est Remaining: 346m 30s
# Processed data for Council Bluffs Police Department, IA - This Process: 22.00s (260/1204) - 97m 32s - Est Remaining: 346m 8s
# Processed data for Dubuque Police Department, IA - This Process: 23.00s (261/1204) - 97m 56s - Est Remaining: 361m 29s
# Processed data for Urbandale Police Department, IA - This Process: 23.00s (262/1204) - 98m 19s - Est Remaining: 361m 6s
# Processed data for Marion Police Department, IA - This Process: 22.00s (263/1204) - 98m 41s - Est Remaining: 345m 2s
# Processed data for Cedar Falls Police Department, IA - This Process: 22.00s (264/1204) - 99m 4s - Est Remaining: 344m 40s
# Processed data for Bettendorf Police Department, IA - This Process: 23.00s (265/1204) - 99m 27s - Est Remaining: 359m 57s
# Processed data for Marshalltown Police Department, IA - This Process: 22.00s (266/1204) - 99m 49s - Est Remaining: 343m 56s
# Processed data for Mason City Police Department, IA - This Process: 22.00s (267/1204) - 100m 11s - Est Remaining: 343m 34s
# Processed data for Ottumwa Police Department, IA - This Process: 21.00s (268/1204) - 100m 33s - Est Remaining: 327m 36s
# Processed data for Fort Dodge Police Department, IA - This Process: 22.00s (269/1204) - 100m 56s - Est Remaining: 342m 50s
# Processed data for Clinton Police Department, IA - This Process: 22.00s (270/1204) - 101m 19s - Est Remaining: 342m 28s
# Processed data for Burlington Police Department, IA - This Process: 21.00s (271/1204) - 101m 40s - Est Remaining: 326m 33s
# Processed data for Muscatine Police Department, IA - This Process: 23.00s (272/1204) - 102m 4s - Est Remaining: 357m 16s
# Processed data for Waukee Police Department, IA - This Process: 21.00s (273/1204) - 102m 25s - Est Remaining: 325m 51s
# Processed data for Johnston Police Department, IA - This Process: 24.00s (274/1204) - 102m 50s - Est Remaining: 372m 0s
# Processed data for Coralville Police Department, IA - This Process: 22.00s (275/1204) - 103m 12s - Est Remaining: 340m 38s
# Processed data for North Liberty Police Department, IA - This Process: 21.00s (276/1204) - 103m 34s - Est Remaining: 324m 48s
# Processed data for Boise Police Department, ID - This Process: 22.00s (277/1204) - 103m 56s - Est Remaining: 339m 54s
# Processed data for Meridian Police Department, ID - This Process: 21.00s (278/1204) - 104m 18s - Est Remaining: 324m 6s
# Processed data for Nampa Police Department, ID - This Process: 22.00s (279/1204) - 104m 40s - Est Remaining: 339m 10s
# Processed data for Idaho Falls Police Department, ID - This Process: 21.00s (280/1204) - 105m 2s - Est Remaining: 323m 24s
# Processed data for Caldwell Police Department, ID - This Process: 22.00s (281/1204) - 105m 24s - Est Remaining: 338m 26s
# Processed data for Pocatello Police Department, ID - This Process: 22.00s (282/1204) - 105m 47s - Est Remaining: 338m 4s
# Processed data for Coeur d'Alene Police Department, ID - This Process: 23.00s (283/1204) - 106m 10s - Est Remaining: 353m 3s
# Processed data for Twin Falls Police Department, ID - This Process: 22.00s (284/1204) - 106m 32s - Est Remaining: 337m 20s
# Processed data for Post Falls Police Department, ID - This Process: 22.00s (285/1204) - 106m 55s - Est Remaining: 336m 58s
# Processed data for Lewiston Police Department, ID - This Process: 22.00s (286/1204) - 107m 17s - Est Remaining: 336m 36s
# Processed data for Rexburg Police Department, ID - This Process: 22.00s (287/1204) - 107m 40s - Est Remaining: 336m 14s
# Processed data for Moscow Police Department, ID - This Process: 22.00s (288/1204) - 108m 2s - Est Remaining: 335m 52s
# Processed data for Mountain Home Police Department, ID - This Process: 22.00s (289/1204) - 108m 24s - Est Remaining: 335m 30s
# Processed data for Chubbuck Police Department, ID - This Process: 22.00s (290/1204) - 108m 47s - Est Remaining: 335m 8s
# Processed data for Jerome Police Department, ID - This Process: 22.00s (291/1204) - 109m 10s - Est Remaining: 334m 46s
# Processed data for Blackfoot Police Department, ID - This Process: 23.00s (292/1204) - 109m 33s - Est Remaining: 349m 36s
# Processed data for Garden City Police Department, ID - This Process: 22.00s (293/1204) - 109m 55s - Est Remaining: 334m 2s
# Processed data for Rathdrum Police Department, ID - This Process: 22.00s (294/1204) - 110m 18s - Est Remaining: 333m 40s
# Processed data for Hailey Police Department, ID - This Process: 22.00s (295/1204) - 110m 40s - Est Remaining: 333m 18s
# Processed data for Sandpoint Police Department, ID - This Process: 23.00s (296/1204) - 111m 3s - Est Remaining: 348m 4s
# Processed data for Payette Police Department, ID - This Process: 22.00s (297/1204) - 111m 26s - Est Remaining: 332m 34s
# Processed data for Emmett Police Department, ID - This Process: 22.00s (298/1204) - 111m 48s - Est Remaining: 332m 12s
# Processed data for Rupert Police Department, ID - This Process: 22.00s (299/1204) - 112m 11s - Est Remaining: 331m 50s
# Processed data for Fruitland Police Department, ID - This Process: 21.00s (300/1204) - 112m 33s - Est Remaining: 316m 24s
# Processed data for Weiser Police Department, ID - This Process: 22.00s (301/1204) - 112m 55s - Est Remaining: 331m 6s
# Processed data for Chicago Police Department, IL - This Process: 22.00s (302/1204) - 113m 18s - Est Remaining: 330m 44s
# Processed data for Aurora Police Department, IL - This Process: 22.00s (303/1204) - 113m 41s - Est Remaining: 330m 22s
# Processed data for Joliet Police Department, IL - This Process: 22.00s (304/1204) - 114m 3s - Est Remaining: 330m 0s
# Processed data for Naperville Police Department, IL - This Process: 22.00s (305/1204) - 114m 26s - Est Remaining: 329m 38s
# Processed data for Rockford Police Department, IL - This Process: 22.00s (306/1204) - 114m 49s - Est Remaining: 329m 16s
# Processed data for Springfield Police Department, IL - This Process: 22.00s (307/1204) - 115m 11s - Est Remaining: 328m 54s
# Processed data for Elgin Police Department, IL - This Process: 22.00s (308/1204) - 115m 33s - Est Remaining: 328m 32s
# Processed data for Waukegan Police Department, IL - This Process: 22.00s (309/1204) - 115m 55s - Est Remaining: 328m 10s
# Processed data for Champaign Police Department, IL - This Process: 22.00s (310/1204) - 116m 18s - Est Remaining: 327m 48s
# Processed data for Cicero Police Department, IL - This Process: 22.00s (311/1204) - 116m 40s - Est Remaining: 327m 26s
# Processed data for Evanston Police Department, IL - This Process: 22.00s (312/1204) - 117m 3s - Est Remaining: 327m 4s
# Processed data for Bloomington Police Department, IL - This Process: 23.00s (313/1204) - 117m 26s - Est Remaining: 341m 33s
# Processed data for Schaumburg Police Department, IL - This Process: 22.00s (314/1204) - 117m 49s - Est Remaining: 326m 20s
# Processed data for Arlington Heights Police Department, IL - This Process: 23.00s (315/1204) - 118m 13s - Est Remaining: 340m 47s
# Processed data for Bolingbrook Police Department, IL - This Process: 23.00s (316/1204) - 118m 36s - Est Remaining: 340m 24s
# Processed data for Decatur Police Department, IL - This Process: 23.00s (317/1204) - 118m 59s - Est Remaining: 340m 1s
# Processed data for Palatine Police Department, IL - This Process: 22.00s (318/1204) - 119m 22s - Est Remaining: 324m 52s
# Processed data for Skokie Police Department, IL - This Process: 23.00s (319/1204) - 119m 45s - Est Remaining: 339m 15s
# Processed data for Des Plaines Police Department, IL - This Process: 22.00s (320/1204) - 120m 7s - Est Remaining: 324m 8s
# Processed data for Orland Park Police Department, IL - This Process: 22.00s (321/1204) - 120m 29s - Est Remaining: 323m 46s
# Processed data for Oak Lawn Police Department, IL - This Process: 22.00s (322/1204) - 120m 52s - Est Remaining: 323m 24s
# Processed data for Berwyn Police Department, IL - This Process: 22.00s (323/1204) - 121m 15s - Est Remaining: 323m 2s
# Processed data for Mount Prospect Police Department, IL - This Process: 22.00s (324/1204) - 121m 37s - Est Remaining: 322m 40s
# Processed data for Tinley Park Police Department, IL - This Process: 22.00s (325/1204) - 122m 0s - Est Remaining: 322m 18s
# Processed data for Oak Park Police Department, IL - This Process: 21.00s (326/1204) - 122m 22s - Est Remaining: 307m 18s
# Processed data for Indianapolis Police Department, IN - This Process: 22.00s (327/1204) - 122m 44s - Est Remaining: 321m 34s
# Processed data for Fort Wayne Police Department, IN - This Process: 21.00s (328/1204) - 123m 6s - Est Remaining: 306m 36s
# Processed data for Evansville Police Department, IN - This Process: 22.00s (329/1204) - 123m 29s - Est Remaining: 320m 50s
# Processed data for South Bend Police Department, IN - This Process: 23.00s (330/1204) - 123m 52s - Est Remaining: 335m 2s
# Processed data for Carmel Police Department, IN - This Process: 22.00s (331/1204) - 124m 15s - Est Remaining: 320m 6s
# Processed data for Fishers Police Department, IN - This Process: 22.00s (332/1204) - 124m 37s - Est Remaining: 319m 44s
# Processed data for Bloomington Police Department, IN - This Process: 22.00s (333/1204) - 125m 0s - Est Remaining: 319m 22s
# Processed data for Hammond Police Department, IN - This Process: 23.00s (334/1204) - 125m 24s - Est Remaining: 333m 30s
# Processed data for Lafayette Police Department, IN - This Process: 22.00s (335/1204) - 125m 46s - Est Remaining: 318m 38s
# Processed data for Gary Police Department, IN - This Process: 22.00s (336/1204) - 126m 9s - Est Remaining: 318m 16s
# Processed data for Noblesville Police Department, IN - This Process: 23.00s (337/1204) - 126m 32s - Est Remaining: 332m 21s
# Processed data for Muncie Police Department, IN - This Process: 21.00s (338/1204) - 126m 54s - Est Remaining: 303m 6s
# Processed data for Greenwood Police Department, IN - This Process: 22.00s (339/1204) - 127m 17s - Est Remaining: 317m 10s
# Processed data for Kokomo Police Department, IN - This Process: 22.00s (340/1204) - 127m 39s - Est Remaining: 316m 48s
# Processed data for Anderson Police Department, IN - This Process: 22.00s (341/1204) - 128m 2s - Est Remaining: 316m 26s
# Processed data for Elkhart Police Department, IN - This Process: 22.00s (342/1204) - 128m 24s - Est Remaining: 316m 4s
# Processed data for Mishawaka Police Department, IN - This Process: 21.00s (343/1204) - 128m 46s - Est Remaining: 301m 21s
# Processed data for Columbus Police Department, IN - This Process: 21.00s (344/1204) - 129m 8s - Est Remaining: 301m 0s
# Processed data for Jeffersonville Police Department, IN - This Process: 22.00s (345/1204) - 129m 30s - Est Remaining: 314m 58s
# Processed data for Lawrence Police Department, IN - This Process: 21.00s (346/1204) - 129m 52s - Est Remaining: 300m 18s
# Processed data for Westfield Police Department, IN - This Process: 21.00s (347/1204) - 130m 14s - Est Remaining: 299m 57s
# Processed data for West Lafayette Police Department, IN - This Process: 23.00s (348/1204) - 130m 37s - Est Remaining: 328m 8s
# Processed data for Portage Police Department, IN - This Process: 22.00s (349/1204) - 130m 59s - Est Remaining: 313m 30s
# Processed data for New Albany Police Department, IN - This Process: 22.00s (350/1204) - 131m 22s - Est Remaining: 313m 8s
# Processed data for Merrillville Police Department, IN - This Process: 22.00s (351/1204) - 131m 45s - Est Remaining: 312m 46s
# Processed data for Wichita Police Department, KS - This Process: 21.00s (352/1204) - 132m 6s - Est Remaining: 298m 12s
# Processed data for Overland Park Police Department, KS - This Process: 21.00s (353/1204) - 132m 28s - Est Remaining: 297m 51s
# Processed data for Park City Police Department, KS - This Process: 23.00s (354/1204) - 132m 51s - Est Remaining: 325m 50s
# Processed data for Olathe Police Department, KS - This Process: 22.00s (355/1204) - 133m 14s - Est Remaining: 311m 18s
# Processed data for Topeka Police Department, KS - This Process: 22.00s (356/1204) - 133m 36s - Est Remaining: 310m 56s
# Processed data for Lawrence Police Department, KS - This Process: 21.00s (357/1204) - 133m 58s - Est Remaining: 296m 27s
# Processed data for Shawnee Police Department, KS - This Process: 21.00s (358/1204) - 134m 20s - Est Remaining: 296m 6s
# Processed data for Lenexa Police Department, KS - This Process: 21.00s (359/1204) - 134m 42s - Est Remaining: 295m 45s
# Processed data for Salina Police Department, KS - This Process: 22.00s (360/1204) - 135m 4s - Est Remaining: 309m 28s
# Processed data for Hutchinson Police Department, KS - This Process: 23.00s (361/1204) - 135m 27s - Est Remaining: 323m 9s
# Processed data for Leavenworth Police Department, KS - This Process: 22.00s (362/1204) - 135m 49s - Est Remaining: 308m 44s
# Processed data for Leawood Police Department, KS - This Process: 22.00s (363/1204) - 136m 12s - Est Remaining: 308m 22s
# Processed data for Garden City Police Department, KS - This Process: 23.00s (364/1204) - 136m 36s - Est Remaining: 322m 0s
# Processed data for Dodge City Police Department, KS - This Process: 22.00s (365/1204) - 136m 58s - Est Remaining: 307m 38s
# Processed data for Derby Police Department, KS - This Process: 22.00s (366/1204) - 137m 20s - Est Remaining: 307m 16s
# Processed data for Emporia Police Department, KS - This Process: 22.00s (367/1204) - 137m 43s - Est Remaining: 306m 54s
# Processed data for Gardner Police Department, KS - This Process: 22.00s (368/1204) - 138m 5s - Est Remaining: 306m 32s
# Processed data for Junction City Police Department, KS - This Process: 22.00s (369/1204) - 138m 27s - Est Remaining: 306m 10s
# Processed data for Prairie Village Police Department, KS - This Process: 22.00s (370/1204) - 138m 50s - Est Remaining: 305m 48s
# Processed data for Hays Police Department, KS - This Process: 22.00s (371/1204) - 139m 12s - Est Remaining: 305m 26s
# Processed data for Pittsburg Police Department, KS - This Process: 22.00s (372/1204) - 139m 35s - Est Remaining: 305m 4s
# Processed data for Liberal Police Department, KS - This Process: 22.00s (373/1204) - 139m 57s - Est Remaining: 304m 42s
# Processed data for Newton Police Department, KS - This Process: 22.00s (374/1204) - 140m 20s - Est Remaining: 304m 20s
# Processed data for Andover Police Department, KS - This Process: 22.00s (375/1204) - 140m 42s - Est Remaining: 303m 58s
# Processed data for Great Bend Police Department, KS - This Process: 22.00s (376/1204) - 141m 4s - Est Remaining: 303m 36s
# Processed data for Lexington Police Department, KY - This Process: 22.00s (377/1204) - 141m 27s - Est Remaining: 303m 14s
# Processed data for Bowling Green Police Department, KY - This Process: 22.00s (378/1204) - 141m 49s - Est Remaining: 302m 52s
# Processed data for Owensboro Police Department, KY - This Process: 22.00s (379/1204) - 142m 11s - Est Remaining: 302m 30s
# Processed data for Covington Police Department, KY - This Process: 23.00s (380/1204) - 142m 34s - Est Remaining: 315m 52s
# Processed data for Georgetown Police Department, KY - This Process: 22.00s (381/1204) - 142m 57s - Est Remaining: 301m 46s
# Processed data for Richmond Police Department, KY - This Process: 21.00s (382/1204) - 143m 19s - Est Remaining: 287m 42s
# Processed data for Florence Police Department, KY - This Process: 22.00s (383/1204) - 143m 42s - Est Remaining: 301m 2s
# Processed data for Elizabethtown Police Department, KY - This Process: 22.00s (384/1204) - 144m 4s - Est Remaining: 300m 40s
# Processed data for Nicholasville Police Department, KY - This Process: 22.00s (385/1204) - 144m 27s - Est Remaining: 300m 18s
# Processed data for Hopkinsville Police Department, KY - This Process: 22.00s (386/1204) - 144m 50s - Est Remaining: 299m 56s
# Processed data for Frankfort Police Department, KY - This Process: 21.00s (387/1204) - 145m 11s - Est Remaining: 285m 57s
# Processed data for Independence Police Department, KY - This Process: 21.00s (388/1204) - 145m 33s - Est Remaining: 285m 36s
# Processed data for Henderson Police Department, KY - This Process: 22.00s (389/1204) - 145m 56s - Est Remaining: 298m 50s
# Processed data for Paducah Police Department, KY - This Process: 21.00s (390/1204) - 146m 18s - Est Remaining: 284m 54s
# Processed data for Radcliff Police Department, KY - This Process: 23.00s (391/1204) - 146m 41s - Est Remaining: 311m 39s
# Processed data for Ashland Police Department, KY - This Process: 22.00s (392/1204) - 147m 3s - Est Remaining: 297m 44s
# Processed data for Madisonville Police Department, KY - This Process: 23.00s (393/1204) - 147m 27s - Est Remaining: 310m 53s
# Processed data for Erlanger Police Department, KY - This Process: 23.00s (394/1204) - 147m 50s - Est Remaining: 310m 30s
# Processed data for Winchester Police Department, KY - This Process: 23.00s (395/1204) - 148m 13s - Est Remaining: 310m 7s
# Processed data for Mount Washington Police Department, KY - This Process: 22.00s (396/1204) - 148m 35s - Est Remaining: 296m 16s
# Processed data for St. Matthews Police Department, KY - This Process: 22.00s (397/1204) - 148m 58s - Est Remaining: 295m 54s
# Processed data for Murray Police Department, KY - This Process: 23.00s (398/1204) - 149m 21s - Est Remaining: 308m 58s
# ...
# Processed data for Fredericksburg Police Department, VA - This Process: 22.00s (1074/1204) - 402m 33s - Est Remaining: 47m 40s
# Processed data for Staunton Police Department, VA - This Process: 23.00s (1075/1204) - 402m 56s - Est Remaining: 49m 27s
# Processed data for Salem Police Department, VA - This Process: 22.00s (1076/1204) - 403m 18s - Est Remaining: 46m 56s
# Processed data for Herndon Police Department, VA - This Process: 22.00s (1077/1204) - 403m 41s - Est Remaining: 46m 34s
# Processed data for Fairfax City Police Department, VA - This Process: 22.00s (1078/1204) - 404m 3s - Est Remaining: 46m 12s
# Processed data for Christiansburg Police Department, VA - This Process: 22.00s (1079/1204) - 404m 25s - Est Remaining: 45m 50s
# Processed data for Burlington Police Department, VT - This Process: 23.00s (1080/1204) - 404m 49s - Est Remaining: 47m 32s
# Processed data for South Burlington Police Department, VT - This Process: 22.00s (1081/1204) - 405m 11s - Est Remaining: 45m 6s
# Processed data for Rutland Police Department, VT - This Process: 21.00s (1082/1204) - 405m 33s - Est Remaining: 42m 42s
# Processed data for Essex Police Department, VT - This Process: 22.00s (1083/1204) - 405m 56s - Est Remaining: 44m 22s
# Processed data for Bennington Police Department, VT - This Process: 22.00s (1084/1204) - 406m 18s - Est Remaining: 44m 0s
# Processed data for Barre Police Department, VT - This Process: 23.00s (1085/1204) - 406m 42s - Est Remaining: 45m 37s
# Processed data for Winooski Police Department, VT - This Process: 23.00s (1086/1204) - 407m 5s - Est Remaining: 45m 14s
# Processed data for Brattleboro Police Department, VT - This Process: 23.00s (1087/1204) - 407m 28s - Est Remaining: 44m 51s
# Processed data for St. Albans Police Department, VT - This Process: 21.00s (1088/1204) - 407m 50s - Est Remaining: 40m 36s
# Processed data for Shelburne Police Department, VT - This Process: 21.00s (1089/1204) - 408m 11s - Est Remaining: 40m 15s
# Processed data for St. Johnsbury Police Department, VT - This Process: 22.00s (1090/1204) - 408m 34s - Est Remaining: 41m 48s
# Processed data for Northfield Police Department, VT - This Process: 22.00s (1091/1204) - 408m 57s - Est Remaining: 41m 26s
# Processed data for Newport Police Department, VT - This Process: 23.00s (1092/1204) - 409m 20s - Est Remaining: 42m 56s
# Processed data for Milton Police Department, VT - This Process: 23.00s (1093/1204) - 409m 43s - Est Remaining: 42m 33s
# Processed data for Bellows Falls Police Department, VT - This Process: 22.00s (1094/1204) - 410m 5s - Est Remaining: 40m 20s
# Processed data for Vergennes Police Department, VT - This Process: 23.00s (1095/1204) - 410m 28s - Est Remaining: 41m 47s
# Processed data for Fair Haven Police Department, VT - This Process: 22.00s (1096/1204) - 410m 51s - Est Remaining: 39m 36s
# Processed data for Swanton Police Department, VT - This Process: 22.00s (1097/1204) - 411m 13s - Est Remaining: 39m 14s
# Processed data for Windsor Police Department, VT - This Process: 23.00s (1098/1204) - 411m 36s - Est Remaining: 40m 38s
# Processed data for Randolph Police Department, VT - This Process: 22.00s (1099/1204) - 411m 59s - Est Remaining: 38m 30s
# Processed data for Bristol Police Department, VT - This Process: 22.00s (1100/1204) - 412m 22s - Est Remaining: 38m 8s
# Processed data for Brandon Police Department, VT - This Process: 23.00s (1101/1204) - 412m 46s - Est Remaining: 39m 29s
# Processed data for Castleton Police Department, VT - This Process: 23.00s (1102/1204) - 413m 9s - Est Remaining: 39m 6s
# Processed data for Chester Police Department, VT - This Process: 22.00s (1103/1204) - 413m 31s - Est Remaining: 37m 2s
# Processed data for Manchester Police Department, VT - This Process: 22.00s (1104/1204) - 413m 53s - Est Remaining: 36m 40s
# Processed data for Seattle Police Department, WA - This Process: 22.00s (1105/1204) - 414m 16s - Est Remaining: 36m 18s
# Processed data for Spokane Police Department, WA - This Process: 22.00s (1106/1204) - 414m 39s - Est Remaining: 35m 56s
# Processed data for Tacoma Police Department, WA - This Process: 22.00s (1107/1204) - 415m 1s - Est Remaining: 35m 34s
# Processed data for Vancouver Police Department, WA - This Process: 22.00s (1108/1204) - 415m 24s - Est Remaining: 35m 12s
# Processed data for Bellevue Police Department, WA - This Process: 22.00s (1109/1204) - 415m 47s - Est Remaining: 34m 50s
# Processed data for Kent Police Department, WA - This Process: 22.00s (1110/1204) - 416m 9s - Est Remaining: 34m 28s
# Processed data for Everett Police Department, WA - This Process: 22.00s (1111/1204) - 416m 31s - Est Remaining: 34m 6s
# Processed data for Spokane Valley Police Department, WA - This Process: 22.00s (1112/1204) - 416m 54s - Est Remaining: 33m 44s
# Processed data for Federal Way Police Department, WA - This Process: 22.00s (1113/1204) - 417m 16s - Est Remaining: 33m 22s
# Processed data for Yakima Police Department, WA - This Process: 22.00s (1114/1204) - 417m 39s - Est Remaining: 33m 0s
# Processed data for Kirkland Police Department, WA - This Process: 22.00s (1115/1204) - 418m 2s - Est Remaining: 32m 38s
# Processed data for Bellingham Police Department, WA - This Process: 22.00s (1116/1204) - 418m 24s - Est Remaining: 32m 16s
# Processed data for Auburn Police Department, WA - This Process: 22.00s (1117/1204) - 418m 46s - Est Remaining: 31m 54s
# Processed data for Kennewick Police Department, WA - This Process: 22.00s (1118/1204) - 419m 9s - Est Remaining: 31m 32s
# Processed data for Pasco Police Department, WA - This Process: 23.00s (1119/1204) - 419m 32s - Est Remaining: 32m 35s
# Processed data for Redmond Police Department, WA - This Process: 22.00s (1120/1204) - 419m 55s - Est Remaining: 30m 48s
# Processed data for Marysville Police Department, WA - This Process: 22.00s (1121/1204) - 420m 17s - Est Remaining: 30m 26s
# Processed data for Sammamish Police Department, WA - This Process: 22.00s (1122/1204) - 420m 40s - Est Remaining: 30m 4s
# Processed data for Lakewood Police Department, WA - This Process: 22.00s (1123/1204) - 421m 2s - Est Remaining: 29m 42s
# Processed data for Richland Police Department, WA - This Process: 21.00s (1124/1204) - 421m 24s - Est Remaining: 28m 0s
# Processed data for Shoreline Police Department, WA - This Process: 22.00s (1125/1204) - 421m 46s - Est Remaining: 28m 58s
# Processed data for Olympia Police Department, WA - This Process: 21.00s (1126/1204) - 422m 8s - Est Remaining: 27m 18s
# Processed data for Lacey Police Department, WA - This Process: 22.00s (1127/1204) - 422m 30s - Est Remaining: 28m 14s
# Processed data for Burien Police Department, WA - This Process: 22.00s (1128/1204) - 422m 53s - Est Remaining: 27m 52s
# Processed data for Bothell Police Department, WA - This Process: 23.00s (1129/1204) - 423m 17s - Est Remaining: 28m 45s
# Processed data for Milwaukee Police Department, WI - This Process: 22.00s (1130/1204) - 423m 39s - Est Remaining: 27m 8s
# Processed data for Madison Police Department, WI - This Process: 23.00s (1131/1204) - 424m 2s - Est Remaining: 27m 59s
# Processed data for Green Bay Police Department, WI - This Process: 22.00s (1132/1204) - 424m 24s - Est Remaining: 26m 24s
# Processed data for Kenosha Police Department, WI - This Process: 22.00s (1133/1204) - 424m 47s - Est Remaining: 26m 2s
# Processed data for Racine Police Department, WI - This Process: 22.00s (1134/1204) - 425m 9s - Est Remaining: 25m 40s
# Processed data for Appleton Police Department, WI - This Process: 21.00s (1135/1204) - 425m 30s - Est Remaining: 24m 9s
# Processed data for Waukesha Police Department, WI - This Process: 23.00s (1136/1204) - 425m 54s - Est Remaining: 26m 4s
# Processed data for Eau Claire Police Department, WI - This Process: 22.00s (1137/1204) - 426m 16s - Est Remaining: 24m 34s
# Processed data for Oshkosh Police Department, WI - This Process: 22.00s (1138/1204) - 426m 38s - Est Remaining: 24m 12s
# Processed data for Janesville Police Department, WI - This Process: 22.00s (1139/1204) - 427m 0s - Est Remaining: 23m 50s
# Processed data for West Allis Police Department, WI - This Process: 22.00s (1140/1204) - 427m 23s - Est Remaining: 23m 28s
# Processed data for La Crosse Police Department, WI - This Process: 22.00s (1141/1204) - 427m 45s - Est Remaining: 23m 6s
# Processed data for Sheboygan Police Department, WI - This Process: 22.00s (1142/1204) - 428m 7s - Est Remaining: 22m 44s
# Processed data for Wauwatosa Police Department, WI - This Process: 22.00s (1143/1204) - 428m 30s - Est Remaining: 22m 22s
# Processed data for Fond du Lac Police Department, WI - This Process: 22.00s (1144/1204) - 428m 52s - Est Remaining: 22m 0s
# Processed data for Brookfield Police Department, WI - This Process: 22.00s (1145/1204) - 429m 15s - Est Remaining: 21m 38s
# Processed data for New Berlin Police Department, WI - This Process: 22.00s (1146/1204) - 429m 38s - Est Remaining: 21m 16s
# Processed data for Wausau Police Department, WI - This Process: 22.00s (1147/1204) - 430m 0s - Est Remaining: 20m 54s
# Processed data for Menomonee Falls Police Department, WI - This Process: 22.00s (1148/1204) - 430m 22s - Est Remaining: 20m 32s
# Processed data for Greenfield Police Department, WI - This Process: 24.00s (1149/1204) - 430m 47s - Est Remaining: 22m 0s
# Processed data for Franklin Police Department, WI - This Process: 23.00s (1150/1204) - 431m 10s - Est Remaining: 20m 42s
# Processed data for Beloit Police Department, WI - This Process: 23.00s (1151/1204) - 431m 33s - Est Remaining: 20m 19s
# Processed data for Oak Creek Police Department, WI - This Process: 23.00s (1152/1204) - 431m 56s - Est Remaining: 19m 56s
# Processed data for Sun Prairie Police Department, WI - This Process: 22.00s (1153/1204) - 432m 19s - Est Remaining: 18m 42s
# Processed data for Manitowoc Police Department, WI - This Process: 22.00s (1154/1204) - 432m 42s - Est Remaining: 18m 20s
# Processed data for Charleston Police Department, WV - This Process: 22.00s (1155/1204) - 433m 5s - Est Remaining: 17m 58s
# Processed data for Huntington Police Department, WV - This Process: 22.00s (1156/1204) - 433m 27s - Est Remaining: 17m 36s
# Processed data for Parkersburg Police Department, WV - This Process: 22.00s (1157/1204) - 433m 50s - Est Remaining: 17m 14s
# Processed data for Morgantown Police Department, WV - This Process: 22.00s (1158/1204) - 434m 13s - Est Remaining: 16m 52s
# Processed data for Wheeling Police Department, WV - This Process: 22.00s (1159/1204) - 434m 35s - Est Remaining: 16m 30s
# Processed data for Weirton Police Department, WV - This Process: 22.00s (1160/1204) - 434m 58s - Est Remaining: 16m 8s
# Processed data for Martinsburg Police Department, WV - This Process: 23.00s (1161/1204) - 435m 21s - Est Remaining: 16m 29s
# Processed data for Fairmont Police Department, WV - This Process: 22.00s (1162/1204) - 435m 43s - Est Remaining: 15m 24s
# Processed data for Beckley Police Department, WV - This Process: 22.00s (1163/1204) - 436m 6s - Est Remaining: 15m 2s
# Processed data for Clarksburg Police Department, WV - This Process: 22.00s (1164/1204) - 436m 29s - Est Remaining: 14m 40s
# Processed data for South Charleston Police Department, WV - This Process: 22.00s (1165/1204) - 436m 51s - Est Remaining: 14m 18s
# Processed data for St. Albans Police Department, WV - This Process: 22.00s (1166/1204) - 437m 13s - Est Remaining: 13m 56s
# Processed data for Vienna Police Department, WV - This Process: 21.00s (1167/1204) - 437m 35s - Est Remaining: 12m 57s
# Processed data for Bluefield Police Department, WV - This Process: 22.00s (1168/1204) - 437m 58s - Est Remaining: 13m 12s
# Processed data for Bridgeport Police Department, WV - This Process: 22.00s (1169/1204) - 438m 20s - Est Remaining: 12m 50s
# Processed data for Oak Hill Police Department, WV - This Process: 23.00s (1170/1204) - 438m 43s - Est Remaining: 13m 2s
# Processed data for Moundsville Police Department, WV - This Process: 22.00s (1171/1204) - 439m 5s - Est Remaining: 12m 6s
# Processed data for Dunbar Police Department, WV - This Process: 22.00s (1172/1204) - 439m 28s - Est Remaining: 11m 44s
# Processed data for Elkins Police Department, WV - This Process: 21.00s (1173/1204) - 439m 49s - Est Remaining: 10m 51s
# Processed data for Hurricane Police Department, WV - This Process: 22.00s (1174/1204) - 440m 12s - Est Remaining: 11m 0s
# Processed data for Nitro Police Department, WV - This Process: 22.00s (1175/1204) - 440m 34s - Est Remaining: 10m 38s
# Processed data for Charles Town Police Department, WV - This Process: 23.00s (1176/1204) - 440m 58s - Est Remaining: 10m 44s
# Processed data for Ranson Police Department, WV - This Process: 21.00s (1177/1204) - 441m 19s - Est Remaining: 9m 27s
# Processed data for Buckhannon Police Department, WV - This Process: 23.00s (1178/1204) - 441m 43s - Est Remaining: 9m 58s
# Processed data for New Martinsville Police Department, WV - This Process: 22.00s (1179/1204) - 442m 6s - Est Remaining: 9m 10s
# Processed data for Cheyenne Police Department, WY - This Process: 22.00s (1180/1204) - 442m 28s - Est Remaining: 8m 48s
# Processed data for Casper Police Department, WY - This Process: 22.00s (1181/1204) - 442m 50s - Est Remaining: 8m 26s
# Processed data for Gillette Police Department, WY - This Process: 22.00s (1182/1204) - 443m 12s - Est Remaining: 8m 4s
# Processed data for Sheridan Police Department, WY - This Process: 24.00s (1183/1204) - 443m 36s - Est Remaining: 8m 24s
# Processed data for Green River Police Department, WY - This Process: 23.00s (1184/1204) - 444m 0s - Est Remaining: 7m 40s
# Processed data for Evanston Police Department, WY - This Process: 23.00s (1185/1204) - 444m 24s - Est Remaining: 7m 17s
# Processed data for Jackson Police Department, WY - This Process: 22.00s (1186/1204) - 444m 46s - Est Remaining: 6m 36s
# Processed data for Riverton Police Department, WY - This Process: 23.00s (1187/1204) - 445m 10s - Est Remaining: 6m 31s
# Processed data for Cody Police Department, WY - This Process: 22.00s (1188/1204) - 445m 33s - Est Remaining: 5m 52s
# Processed data for Rawlins Police Department, WY - This Process: 22.00s (1189/1204) - 445m 55s - Est Remaining: 5m 30s
# Processed data for Lander Police Department, WY - This Process: 21.00s (1190/1204) - 446m 17s - Est Remaining: 4m 54s
# Processed data for Powell Police Department, WY - This Process: 23.00s (1191/1204) - 446m 41s - Est Remaining: 4m 59s
# Processed data for Douglas Police Department, WY - This Process: 23.00s (1192/1204) - 447m 4s - Est Remaining: 4m 36s
# Processed data for Torrington Police Department, WY - This Process: 23.00s (1193/1204) - 447m 27s - Est Remaining: 4m 13s
# Processed data for Worland Police Department, WY - This Process: 22.00s (1194/1204) - 447m 49s - Est Remaining: 3m 40s
# Processed data for Buffalo Police Department, WY - This Process: 22.00s (1195/1204) - 448m 12s - Est Remaining: 3m 18s
# Processed data for Mills Police Department, WY - This Process: 21.00s (1196/1204) - 448m 34s - Est Remaining: 2m 48s
# Processed data for Wheatland Police Department, WY - This Process: 22.00s (1197/1204) - 448m 56s - Est Remaining: 2m 34s
# Processed data for Newcastle Police Department, WY - This Process: 21.00s (1198/1204) - 449m 18s - Est Remaining: 2m 6s
# Processed data for Glenrock Police Department, WY - This Process: 22.00s (1199/1204) - 449m 41s - Est Remaining: 1m 50s
# Processed data for Evansville Police Department, WY - This Process: 21.00s (1200/1204) - 450m 2s - Est Remaining: 1m 24s
# Processed data for Kemmerer Police Department, WY - This Process: 23.00s (1201/1204) - 450m 25s - Est Remaining: 1m 9s
# Processed data for Rock Springs Police Department, WY - This Process: 22.00s (1202/1204) - 450m 48s - Est Remaining: 0m 44s
# Processed data for Greybull Police Department, WY - This Process: 23.00s (1203/1204) - 451m 11s - Est Remaining: 0m 23s
# Processed data for Lovell Police Department, WY - This Process: 22.00s (1204/1204) - 451m 34s - Est Remaining: 0m 0s
# Data saved to ../Resources/Agency/top_25_state_cities_crime_data.csv

# %%
# Load the data
df_cities_plot = pd.read_csv("../Resources/Agency/top_25_state_cities_crime_data.csv")

# Remove rows where the State is "AK" or "HI"
df_cities_plot = df_cities_plot[~df_cities_plot['State'].isin(['AK', 'HI'])]

# Remove rows where both "Violent Crime" and "Property Crime" are 0
df_cities_plot = df_cities_plot[~((df_cities_plot['Violent Crime'] == 0) & (df_cities_plot['Property Crime'] == 0))]
df_cities_plot["Crime Rate (Per 100k)"] = df_cities_plot["Crime Rate (Per 100k)"].map("{:.2f}".format)

# Create the map plot
map_plot_1 = df_cities_plot.hvplot.points(
    "Longitude",
    "Latitude",
    geo=True,
    tiles="OSM",
    size="Crime Rate(Per 100k)",
    color="Poverty Rate",
    cmap="RdYlBu_r",
    title="Top 25 Cities by State - Crime Data",
    width=1600,
    height=800,
    responsive=True,  # Add this parameter
    shared_axes=False,  # Add this parameter
    xaxis=None,  # Add this parameter
    yaxis=None,  # Add this parameter
    hover_cols=["City", "State"],
    scale = .1
)

# Display the plot
map_plot_1
# Out:
# WARNING:param.GeoOverlayPlot03000: responsive mode could not be enabled because fixed width and height were specified.
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Longitude,Latitude]   (Poverty Rate,Crime Rate(Per 100k),City,State)
